# %% [markdown]
# ## Install the PGR-TK package

# %% [markdown]
# If neccessary, install the package into your python environment
# ```
# pip install --force /code/pgrtk-0.3.2-cp38-cp38-linux_x86_64.whl
# ```

# %%
import pgrtk
import os
import matplotlib.pyplot as plt
from IPython.display import SVG
# %matplotlib inline

# %%
pgrtk.__version__
# Out:
# 'pgrtk 0.3.4 (main:59af6a0, release build, linux [x86_64] [rustc 1.62.0 (a8314ef7d 2022-06-27)])'

# %%
os.chdir("/results")

# %% [markdown]
# ## Lazy load the the AGCfile for fetching sequences

# %%
ref_db =pgrtk.AGCFile("/data/pgr-tk-HGRP-y1-evaluation-set-v0.agc") # lazy load an agc file of the reference without any SHIMMER index

# %% [markdown]
# ## Load the index into memory
# The loads the index into the memory. It takes about one minute.

# %%
# %%time
sdb = pgrtk.SeqIndexDB()
sdb.load_from_agc_index("/data/pgr-tk-HGRP-y1-evaluation-set-v0")
# Out:
# CPU times: user 23 s, sys: 6min 39s, total: 7min 2s
# Wall time: 30.5 s

# %% [markdown]
# We can see the specification about how SHIMMERs are computed using the `get_shmmr_spec()` method.

# %%
sdb.get_shmmr_spec() # window_size, k_mer_size, hieraical_reduction_factor, min_span, use_k_mer_sketch_other_than_minimizer
# Out:
# (80, 56, 4, 64, False)

# %% [markdown]
# ## Query the database with the sequence of the region

# %% [markdown]
# We use a copy of the annotation for IGV hg19 to look up the chromosome and locations of the gene of interest.
# We can fetch the region of interest with `ref_db`. Let's fetch the whole region and do a dot plot to examine the repeat structure.

# %%
ref_file_name, roi_chr, roi_b, roi_e = 'hg19_tagged.fa', 'chr5_hg19', 69345349, 70248838
padding = 700000
roi_len = roi_e - roi_b
#get a segment of a reference
roi_seq = ref_db.get_sub_seq(ref_file_name, roi_chr, roi_b-padding, roi_e+padding)
x, y = pgrtk.get_shmmr_dots(roi_seq, roi_seq, 32, 32, 12, 2)
plt.plot(x, y, ".", markersize=0.5)
print(x[0])
plt.xlim(0,len(roi_seq))
plt.ylim(0,len(roi_seq))
# Out:
# 1054
# (0.0, 2303489.0)

# %%
#find hits in the pangenomic reference
aln_range = pgrtk.query_sdb(sdb, roi_seq, merge_range_tol=1000000)

print("The number of hits is", len(aln_range))

count = 0
for sid, rgns in aln_range.items():
    count += len(rgns)

print("The total aligned regions is", count)
# Out:
# The number of hits is 471
# The total aligned regions is 724

# %% [markdown]
# We can examine, the target region sizes.

# %%
rgn_lengths = []
for k in list(aln_range.keys()):
    b, e = aln_range[k][0][0:2]
    print(sdb.seq_info[k], "target region", b, "-", e, "len:", e-b )
    rgn_lengths.append(e-b)
# Out:
# ('HG002#2#JAHKSD010000001.1', 'HG002.maternal.f1_assembly_v2_genbank.fa', 110635364) target region 109492897 - 110633557 len: 1140660
# ('HG01175#2#JAHALZ010000056.1', 'HG01175.maternal.f1_assembly_v2_genbank.fa', 23599649) target region 21505376 - 23599397 len: 2094021
# ('HG02818#2#JAHEOR010000017.1', 'HG02818.maternal.f1_assembly_v2_genbank.fa',
1', 'HG00673.maternal.f1_assembly_v2_genbank.fa', 28692546) target region 4384883 - 4385593 len: 710
# ('HG00733#2#JAHEPP010000002.1', 'HG00733.maternal.f1_assembly_v2_genbank.fa', 78555672) target region 78048232 - 78554859 len: 506627
# ('NA19240#1#JAHEOM010000009.1', 'NA19240.paternal.f1_assembly_v2_genbank.fa', 21511437) target region 20711868 - 21511383 len: 799515
# ('HG01109#1#JAHEPA010000471.1', 'HG01109.paternal.f1_assembly_v2_genbank.fa', 26443) target region 229 - 26294 len: 26065
# ('HG01978#1#JAGYVS010000035.1', 'HG01978.paternal.f1_assembly_v2_genbank.fa', 60616846) target region 57784443 - 57785216 len: 773
# ('HG02080#2#JAHEOV010000210.1', 'HG02080.maternal.f1_assembly_v2_genbank.fa', 2034606) target region 1446315 - 1447088 len: 773
# ('HG00733#2#JAHEPP010000377.1', 'HG00733.maternal.f1_assembly_v2_genbank.fa', 41848) target region 639 - 40710 len: 40071
# ('HG03492#2#JAHEPH010000009.1', 'HG03492.maternal.f1_assembly_v2_genbank.fa', 52792433) target region 3486782 - 3686958 len: 200176
# ('HG02630#2#JAHAOP010000126.1', 'HG02630.maternal.f1_assembly_v2_genbank.fa', 9362958) target region 8075312 - 9362739 len: 1287427
# ('HG03486#2#JAHEOP010000125.1', 'HG03486.maternal.f1_assembly_v2_genbank.fa', 20434355) target region 8074873 - 9615259 len: 1540386
# ('NA18906#2#JAHEON010000085.1', 'NA18906.maternal.f1_assembly_v2_genbank.fa', 50576078) target region 50092455 - 50574529 len: 482074
# ('HG01928#1#JAGYVQ010000020.1', 'HG01928.paternal.f1_assembly_v2_genbank.fa', 40778302) target region 2573058 - 2573831 len: 773
# ('HG02145#1#JAHKSG010000078.1', 'HG02145.paternal.f1_assembly_v2_genbank.fa', 20764127) target region 19832147 - 20764096 len: 931949
# ('HG01928#2#JAGYVP010000010.1', 'HG01928.maternal.f1_assembly_v2_genbank.fa', 152507898) target region 727171 - 727881 len: 710
# ('HG00733#1#JAHEPQ010000391.1', 'HG00733.paternal.f1_assembly_v2_genbank.fa', 29594) target region 369 - 28955 len: 28586
# ('HG01109#1#JAHEPA010000462.1', 'HG01109.paternal.f1_assembly_v2_genbank.fa', 40712) target region 1167 - 40631 len: 39464
# ('HG02818#2#JAHEOR010000057.1', 'HG02818.maternal.f1_assembly_v2_genbank.fa', 21137150) target region 20687451 - 21137057 len: 449606
# ('HG02486#2#JAGYVL010000269.1', 'HG02486.maternal.f1_assembly_v2_genbank.fa', 36561) target region 541 - 36314 len: 35773
# ('HG02572#2#JAHAOV010000062.1', 'HG02572.maternal.f1_assembly_v2_genbank.fa', 20192271) target region 19647055 - 20192105 len: 545050
# ('HG02148#2#JAHAMF010000011.1', 'HG02148.maternal.f1_assembly_v2_genbank.fa', 2572160) target region 1446606 - 1447379 len: 773
# ('HG00621#1#JAHBCD010000159.1', 'HG00621.paternal.f1_assembly_v2_genbank.fa', 104381) target region 269 - 104121 len: 103852
# ('HG03486#1#JAHEOQ010000138.1', 'HG03486.paternal.f1_assembly_v2_genbank.fa', 11789073) target region 459 - 970445 len: 969986
# ('HG00673#1#JAHBBZ010000153.1', 'HG00673.paternal.f1_assembly_v2_genbank.fa', 334421) target region 458 - 334353 len: 333895
# ('NA20129#2#JAHEPD010000043.1', 'NA20129.maternal.f1_assembly_v2_genbank.fa', 11314912) target region 11133463 - 11133970 len: 507
# ('HG002#2#JAHKSD010000032.1', 'HG002.maternal.f1_assembly_v2_genbank.fa', 47503194) target region 22299994 - 22300704 len: 710
# ('HG01123#1#JAGYYZ010000018.1', 'HG01123.paternal.f1_assembly_v2_genbank.fa', 43978510) target region 13631262 - 13631769 len: 507
# ('HG01258#2#JAGYYU010000011.1', 'HG01258.maternal.f1_assembly_v2_genbank.fa', 39568798) target region 1428587 - 1429360 len: 773
# ('HG01928#1#JAGYVQ010000005.1', 'HG01928.paternal.f1_assembly_v2_genbank.fa', 154533993) target region 103697243 - 105217271 len: 1520028
# ('HG02622#2#JAHAON010000041.1', 'HG02622.maternal.f1_assembly_v2_genbank.fa', 60041455) target region 57863753 - 57864526 len: 773
# ('HG00733#1#JAHEPQ010000001.1', 'HG00733.paternal.f1_assembly_v2_genbank.fa',
1', 'HG02257.maternal.f1_assembly_v2_genbank.fa', 6417738) target region 6150563 - 6417670 len: 267107
# ('HG00438#2#JAHBCA010000063.1', 'HG00438.maternal.f1_assembly_v2_genbank.fa', 23494028) target region 408 - 382351 len: 381943
# ('HG00733#2#JAHEPP010000060.1', 'HG00733.maternal.f1_assembly_v2_genbank.fa', 27483925) target region 2084432 - 2085205 len: 773
# ('HG03453#2#JAGYVV010000225.1', 'HG03453.maternal.f1_assembly_v2_genbank.fa', 3110490) target region 1446288 - 1447061 len: 773
# ('HG00735#1#JAHBCH010000038.1', 'HG00735.paternal.f1_assembly_v2_genbank.fa', 21429372) target region 20285055 - 21429044 len: 1143989
# ('HG005#2#JAHEPN010000158.1', 'HG005.maternal.f1_assembly_v2_genbank.fa', 98727) target region 422 - 97922 len: 97500
# ('HG00741#2#JAHALX010000117.1', 'HG00741.maternal.f1_assembly_v2_genbank.fa', 2689616) target region 1443829 - 1444602 len: 773
# ('HG02723#2#JAHEOT010000075.1', 'HG02723.maternal.f1_assembly_v2_genbank.fa', 11815612) target region 10831689 - 11813337 len: 981648
# ('HG00733#2#JAHEPP010000562.1', 'HG00733.maternal.f1_assembly_v2_genbank.fa', 28839) target region 574 - 28704 len: 28130
# ('HG02572#1#JAHAOW010000129.1', 'HG02572.paternal.f1_assembly_v2_genbank.fa', 2423464) target region 66 - 1232672 len: 1232606
# ('HG02257#2#JAGYVH010000178.1', 'HG02257.maternal.f1_assembly_v2_genbank.fa', 288841) target region 762 - 288509 len: 287747
# ('HG01071#1#JAHBCF010000048.1', 'HG01071.paternal.f1_assembly_v2_genbank.fa', 19342084) target region 17862873 - 17863646 len: 773
# ('HG01361#2#JAGYYW010000027.1', 'HG01361.maternal.f1_assembly_v2_genbank.fa', 97721731) target region 97127837 - 97721271 len: 593434
# ('HG00733#2#JAHEPP010000559.1', 'HG00733.maternal.f1_assembly_v2_genbank.fa', 126058) target region 7569 - 125732 len: 118163
# ('HG02630#2#JAHAOP010000057.1', 'HG02630.maternal.f1_assembly_v2_genbank.fa', 34669722) target region 34461212 - 34669569 len: 208357
# ('HG00733#2#JAHEPP010000432.1', 'HG00733.maternal.f1_assembly_v2_genbank.fa', 127471) target region 4753 - 127022 len: 122269
# ('HG002#1#JAHKSE010000162.1', 'HG002.paternal.f1_assembly_v2_genbank.fa', 23139846) target region 175 - 953142 len: 952967
# ('HG03516#1#JAGYYT010000143.1', 'HG03516.paternal.f1_assembly_v2_genbank.fa', 313316) target region 321 - 313192 len: 312871
# ('HG01123#2#JAGYYY010000050.1', 'HG01123.maternal.f1_assembly_v2_genbank.fa', 59396933) target region 57763689 - 57764462 len: 773
# ('HG03540#2#JAGYVX010000152.1', 'HG03540.maternal.f1_assembly_v2_genbank.fa', 2380229) target region 936316 - 937089 len: 773
# ('HG01175#2#JAHALZ010000030.1', 'HG01175.maternal.f1_assembly_v2_genbank.fa', 2720848) target region 1447123 - 1447896 len: 773
# ('HG03516#1#JAGYYT010000016.1', 'HG03516.paternal.f1_assembly_v2_genbank.fa', 22521343) target region 1183 - 256461 len: 255278
# ('HG02109#2#JAHEPF010000111.1', 'HG02109.maternal.f1_assembly_v2_genbank.fa', 16629911) target region 13884007 - 15969284 len: 2085277
# ('HG01358#2#JAGYZA010000040.1', 'HG01358.maternal.f1_assembly_v2_genbank.fa', 43960639) target region 33277313 - 33278533 len: 1220
# ('HG002#1#JAHKSE010000032.1', 'HG002.paternal.f1_assembly_v2_genbank.fa', 47528663) target region 22336290 - 22337000 len: 710
# ('HG02723#1#JAHEOU010000015.1', 'HG02723.paternal.f1_assembly_v2_genbank.fa', 30513748) target region 20687390 - 22440714 len: 1753324
# ('HG00621#1#JAHBCD010000096.1', 'HG00621.paternal.f1_assembly_v2_genbank.fa',
1', 'HG02148.maternal.f1_assembly_v2_genbank.fa', 44147970) target region 30080317 - 30081538 len: 1221
# ('HG02630#1#JAHAOQ010000041.1', 'HG02630.paternal.f1_assembly_v2_genbank.fa', 24763658) target region 14207249 - 16689640 len: 2482391
# ('HG00673#1#JAHBBZ010000199.1', 'HG00673.paternal.f1_assembly_v2_genbank.fa', 445283) target region 2003 - 442507 len: 440504
# ('HG00673#2#JAHBBY010000293.1', 'HG00673.maternal.f1_assembly_v2_genbank.fa', 31767) target region 170 - 31383 len: 31213
# ('HG03516#2#JAGYYS010000061.1', 'HG03516.maternal.f1_assembly_v2_genbank.fa', 49051857) target region 27606166 - 27607772 len: 1606
# ('HG01891#1#JAGYVO010000217.1', 'HG01891.paternal.f1_assembly_v2_genbank.fa', 97364) target region 189 - 96988 len: 96799
# ('HG01952#1#JAHAME010000056.1', 'HG01952.paternal.f1_assembly_v2_genbank.fa', 25057940) target region 12237601 - 12504096 len: 266495
# ('HG02080#1#JAHEOW010000064.1', 'HG02080.paternal.f1_assembly_v2_genbank.fa', 2723521) target region 1276950 - 1277723 len: 773
# ('HG01952#1#JAHAME010000053.1', 'HG01952.paternal.f1_assembly_v2_genbank.fa', 21734943) target region 21366159 - 21683278 len: 317119
# ('HG01106#1#JAHAMC010000039.1', 'HG01106.paternal.f1_assembly_v2_genbank.fa', 39096129) target region 8956551 - 8958572 len: 2021
# ('HG01891#1#JAGYVO010000084.1', 'HG01891.paternal.f1_assembly_v2_genbank.fa', 6252935) target region 5846763 - 6252780 len: 406017
# ('HG02257#2#JAGYVH010000012.1', 'HG02257.maternal.f1_assembly_v2_genbank.fa', 103625707) target region 103118193 - 103625073 len: 506880
# ('HG02723#2#JAHEOT010000033.1', 'HG02723.maternal.f1_assembly_v2_genbank.fa', 30594632) target region 14151724 - 14153744 len: 2020
# ('HG01978#2#JAGYVR010000047.1', 'HG01978.maternal.f1_assembly_v2_genbank.fa', 21524316) target region 21342107 - 21343713 len: 1606
# ('HG02818#1#JAHEOS010000218.1', 'HG02818.paternal.f1_assembly_v2_genbank.fa', 2658101) target region 1666058 - 1666831 len: 773
# ('HG03098#2#JAHEPL010000073.1', 'HG03098.maternal.f1_assembly_v2_genbank.fa', 2105876) target region 1436530 - 1437303 len: 773
# ('HG01952#1#JAHAME010000044.1', 'HG01952.paternal.f1_assembly_v2_genbank.fa', 33720779) target region 2644098 - 2644871 len: 773
# ('NA19240#2#JAHEOL010000031.1', 'NA19240.maternal.f1_assembly_v2_genbank.fa', 24328808) target region 12197969 - 12199989 len: 2020
# ('HG00733#1#JAHEPQ010000286.1', 'HG00733.paternal.f1_assembly_v2_genbank.fa', 17573) target region 2020 - 15936 len: 13916
# ('HG00673#2#JAHBBY010000148.1', 'HG00673.maternal.f1_assembly_v2_genbank.fa', 2280988) target region 1444729 - 1445502 len: 773
# ('NA20129#2#JAHEPD010000322.1', 'NA20129.maternal.f1_assembly_v2_genbank.fa', 903493) target region 2960 - 903418 len: 900458
# ('chr6_hg38', 'hg38_tagged.fa', 170805979) target region 57771445 - 57772218 len: 773
# ('HG03098#1#JAHEPM010000365.1', 'HG03098.paternal.f1_assembly_v2_genbank.fa', 72701) target region 9494 - 72694 len: 63200
# ('HG002#2#JAHKSD010000181.1', 'HG002.maternal.f1_assembly_v2_genbank.fa', 864702) target region 240 - 862136 len: 861896
# ('HG02723#2#JAHEOT010000148.1', 'HG02723.maternal.f1_assembly_v2_genbank.fa', 8569109) target region 8075675 - 8568269 len: 492594
# ('HG00735#2#JAHBCG010000228.1', 'HG00735.maternal.f1_assembly_v2_genbank.fa', 72095) target region 163 - 71837 len: 71674
# ('NA19240#2#JAHEOL010000149.1', 'NA19240.maternal.f1_assembly_v2_genbank.fa', 2087197) target region 1703410 - 1704183 len: 773
# ('HG00741#1#JAHALY010000017.1', 'HG00741.paternal.f1_assembly_v2_genbank.fa', 104328285) target region 103156161 - 104327468 len: 1171307
# ('HG03486#2#JAHEOP010000005.1', 'HG03486.maternal.f1_assembly_v2_genbank.fa', 25584847) target region 3467188 - 4533909 len: 1066721
# ('HG03492#1#JAHEPI010000023.1', 'HG03492.paternal.f1_assembly_v2_genbank.fa', 25435688) target region 16433663 - 16434883 len: 1220
# ('HG01361#1#JAGYYX010000056.1', 'HG01361.paternal.f1_assembly_v2_genbank.fa', 38703528) target region 16177060 - 16179081 len: 2021
# ('HG03540#1#JAGYVY010000044.1', 'HG03540.paternal.f1_assembly_v2_genbank.fa', 4077146) target region 2632294 - 2633067 len: 773
# ('HG01928#2#JAGYVP010000017.1', 'HG01928.maternal.f1_assembly_v2_genbank.fa', 59868708) target region 57821158 - 57821931 len: 773
# ('HG02572#2#JAHAOV010000577.1', 'HG02572.maternal.f1_assembly_v2_genbank.fa', 50318) target region 64 - 50154 len: 50090
# ('HG02622#2#JAHAON010000060.1', 'HG02622.maternal.f1_assembly_v2_genbank.fa', 20167488) target region 19765058 - 20161917 len: 396859
# ('HG002#2#JAHKSD010000048.1', 'HG002.maternal.f1_assembly_v2_genbank.fa', 2567406) target region 2238854 - 2567139 len: 328285
# ('HG02080#1#JAHEOW010000040.1', 'HG02080.paternal.f1_assembly_v2_genbank.fa', 19875285) target region 2085 - 240871 len: 238786
# ('HG02257#1#JAGYVI010000204.1', 'HG02257.paternal.f1_assembly_v2_genbank.fa', 56317) target region 369 - 55947 len: 55578
# ('HG01071#2#JAHBCE010000224.1', 'HG01071.maternal.f1_assembly_v2_genbank.fa', 36114) target region 117 - 35716 len: 35599
# ('HG01358#1#JAGYZB010000030.1', 'HG01358.paternal.f1_assembly_v2_genbank.fa', 19764810) target region 1903946 - 1904719 len: 773
# ('HG002#2#JAHKSD010000045.1', 'HG002.maternal.f1_assembly_v2_genbank.fa', 32356768) target region 1363790 - 1364563 len: 773
# ('HG00741#1#JAHALY010000008.1', 'HG00741.paternal.f1_assembly_v2_genbank.fa', 22470913) target region 21815207 - 22470509 len: 655302
# ('NA19240#2#JAHEOL010000013.1', 'NA19240.maternal.f1_assembly_v2_genbank.fa', 15446026) target region 14975090 - 15232085 len: 256995
# ('NA19240#1#JAHEOM010000004.1', 'NA19240.paternal.f1_assembly_v2_genbank.fa', 59408378) target region 36076695 - 36077468 len: 773
# ('HG01106#1#JAHAMC010000012.1', 'HG01106.paternal.f1_assembly_v2_genbank.fa', 130704444) target region 109409159 - 110969811 len: 1560652
# ('NA21309#2#JAHEPB010000131.1', 'NA21309.maternal.f1_assembly_v2_genbank.fa', 7150398) target region 1573486 - 1574711 len: 1225
# ('HG02055#2#JAHEPJ010000119.1', 'HG02055.maternal.f1_assembly_v2_genbank.fa', 2525797) target region 1441773 - 1442546 len: 773
# ('HG01123#2#JAGYYY010000241.1', 'HG01123.maternal.f1_assembly_v2_genbank.fa', 95495) target region 2808 - 95210 len: 92402
# ('HG02622#2#JAHAON010000051.1', 'HG02622.maternal.f1_assembly_v2_genbank.fa', 39181303) target region 8785344 - 8939823 len: 154479
# ('HG02818#2#JAHEOR010000182.1', 'HG02818.maternal.f1_assembly_v2_genbank.fa', 8815843) target region 8072514 - 8814657 len: 742143
# ('HG02886#1#JAHAOU010000047.1', 'HG02886.paternal.f1_assembly_v2_genbank.fa', 25501325) target region 8974270 - 8976290 len: 2020
# ('HG01175#1#JAHAMA010000030.1', 'HG01175.paternal.f1_assembly_v2_genbank.fa', 36806136) target region 14830706 - 15751064 len: 920358
# ('HG02886#2#JAHAOT010000003.1', 'HG02886.maternal.f1_assembly_v2_genbank.fa', 33659657) target region 811029 - 811802 len: 773
# ('HG01361#2#JAGYYW010000085.1', 'HG01361.maternal.f1_assembly_v2_genbank.fa', 20359269) target region 19751899 - 20359136 len: 607237
# ('HG005#2#JAHEPN010000086.1', 'HG005.maternal.f1_assembly_v2_genbank.fa', 220305) target region 337 - 219473 len: 219136
# ('HG03492#1#JAHEPI010000008.1', 'HG03492.paternal.f1_assembly_v2_genbank.fa', 34781986) target region 21662985 - 23963900 len: 2300915
# ('HG01358#1#JAGYZB010000021.1', 'HG01358.paternal.f1_assembly_v2_genbank.fa', 43036729) target region 10460874 - 10461381 len: 507
# ('HG00621#1#JAHBCD010000033.1', 'HG00621.paternal.f1_assembly_v2_genbank.fa', 63401524) target region 39520705 - 40966992 len: 1446287
# ('HG00741#1#JAHALY010000250.1', 'HG00741.paternal.f1_assembly_v2_genbank.fa', 44791) target region 333 - 44258 len: 43925
# ('HG00438#1#JAHBCB010000105.1', 'HG00438.paternal.f1_assembly_v2_genbank.fa', 664645) target region 84 - 663782 len: 663698
# ('HG02257#2#JAGYVH010000103.1', 'HG02257.maternal.f1_assembly_v2_genbank.fa', 438843) target region 1228 - 438182 len: 436954
# ('HG02630#1#JAHAOQ010000244.1', 'HG02630.paternal.f1_assembly_v2_genbank.fa', 156142) target region 31197 - 155872 len: 124675
# ('HG02559#2#JAGYVJ010000014.1', 'HG02559.maternal.f1_assembly_v2_genbank.fa', 73979660) target region 50412107 - 52010093 len: 1597986
# ('HG02148#2#JAHAMF010000003.1', 'HG02148.maternal.f1_assembly_v2_genbank.fa', 104115855) target region 103185341 - 104115702 len: 930361
# ('NA21309#2#JAHEPB010000119.1', 'NA21309.maternal.f1_assembly_v2_genbank.fa', 9732944) target region 8075959 - 9732913 len: 1656954
# ('HG00438#1#JAHBCB010000102.1', 'HG00438.paternal.f1_assembly_v2_genbank.fa', 2594165) target region 1145834 - 1146607 len: 773
# ('NA21309#1#JAHEPC010000120.1', 'NA21309.paternal.f1_assembly_v2_genbank.fa', 28768613) target region 12333317 - 12335337 len: 2020
# ('HG01978#2#JAGYVR010000008.1', 'HG01978.maternal.f1_assembly_v2_genbank.fa', 31321748) target region 21555045 - 23793735 len: 2238690
# ('HG01361#1#JAGYYX010000283.1', 'HG01361.paternal.f1_assembly_v2_genbank.fa', 20621) target region 366 - 19651 len: 19285
# ('HG02572#1#JAHAOW010000048.1', 'HG02572.paternal.f1_assembly_v2_genbank.fa', 30847050) target region 4688307 - 4689017 len: 710
# ('HG02559#1#JAGYVK010000057.1', 'HG02559.paternal.f1_assembly_v2_genbank.fa', 80066) target region 5513 - 6734 len: 1221
# ('HG00741#1#JAHALY010000114.1', 'HG00741.paternal.f1_assembly_v2_genbank.fa', 2532467) target region 1443829 - 1444602 len: 773
# ('HG01358#1#JAGYZB010000387.1', 'HG01358.paternal.f1_assembly_v2_genbank.fa', 79689) target region 95 - 79554 len: 79459
# ('HG03098#1#JAHEPM010000081.1', 'HG03098.paternal.f1_assembly_v2_genbank.fa', 21867278) target region 21240714 - 21867150 len: 626436
# ('HG02109#1#JAHEPG010000093.1', 'HG02109.paternal.f1_assembly_v2_genbank.fa', 34533756) target region 10832405 - 12319615 len: 1487210
# ('HG02080#2#JAHEOV010000184.1', 'HG02080.maternal.f1_assembly_v2_genbank.fa', 22080302) target region 13097775 - 13098995 len: 1220
# ('HG02723#1#JAHEOU010000064.1', 'HG02723.paternal.f1_assembly_v2_genbank.fa', 2403046) target region 957978 - 958751 len: 773
# ('HG03492#2#JAHEPH010000361.1', 'HG03492.maternal.f1_assembly_v2_genbank.fa', 155390) target region 879 - 155298 len: 154419
# ('HG02886#1#JAHAOU010000029.1', 'HG02886.paternal.f1_assembly_v2_genbank.fa', 12442357) target region 10996305 - 10997078 len: 773
# ('HG02109#2#JAHEPF010000030.1', 'HG02109.maternal.f1_assembly_v2_genbank.fa', 25707981) target region 3925225 - 4814975 len: 889750
# ('HG01952#2#JAHAMD010000055.1', 'HG01952.maternal.f1_assembly_v2_genbank.fa', 49561565) target region 912083 - 912793 len: 710
# ('HG00735#1#JAHBCH010000199.1', 'HG00735.paternal.f1_assembly_v2_genbank.fa', 143029) target region 92 - 142909 len: 142817
# ('HG00438#1#JAHBCB010000090.1', 'HG00438.paternal.f1_assembly_v2_genbank.fa', 7977496) target region 420 - 445144 len: 444724
# ('chr5_chm13', 'chm13_tagged.fa', 182045439) target region 21306309 - 22284193 len: 977884
# ('NA20129#2#JAHEPD010000026.1', 'NA20129.maternal.f1_assembly_v2_genbank.fa', 23988694) target region 11982422 - 11983132 len: 710
# ('HG00673#1#JAHBBZ010000260.1', 'HG00673.paternal.f1_assembly_v2_genbank.fa', 43260) target region 808 - 42960 len: 42152
# ('HG01106#2#JAHAMB010000003.1', 'HG01106.maternal.f1_assembly_v2_genbank.fa', 240888) target region 11724 - 240449 len: 228725
# ('HG01891#1#JAGYVO010000154.1', 'HG01891.paternal.f1_assembly_v2_genbank.fa', 355849) target region 364 - 355570 len: 355206
# ('NA19240#2#JAHEOL010000358.1', 'NA19240.maternal.f1_assembly_v2_genbank.fa', 33674) target region 1099 - 33529 len: 32430
# ('HG01891#1#JAGYVO010000024.1', 'HG01891.paternal.f1_assembly_v2_genbank.fa', 32274981) target region 1150268 - 1151041 len: 773
# ('HG002#1#JAHKSE010000066.1', 'HG002.paternal.f1_assembly_v2_genbank.fa', 32583635) target region 31142924 - 31143697 len: 773
# ('HG00621#2#JAHBCC010000005.1', 'HG00621.maternal.f1_assembly_v2_genbank.fa', 59876178) target region 57724416 - 57725189 len: 773
# ('HG01361#1#JAGYYX010000011.1', 'HG01361.paternal.f1_assembly_v2_genbank.fa', 71652996) target region 50089752 - 51816358 len: 1726606
# ('HG03098#1#JAHEPM010000063.1', 'HG03098.paternal.f1_assembly_v2_genbank.fa', 4447009) target region 2292530 - 2293303 len: 773
# ('NA19240#1#JAHEOM010000343.1', 'NA19240.paternal.f1_assembly_v2_genbank.fa', 105363) target region 1154 - 104452 len: 103298
# ('HG00741#2#JAHALX010000012.1', 'HG00741.maternal.f1_assembly_v2_genbank.fa', 147827812) target region 137918 - 138425 len: 507
# ('HG01361#2#JAGYYW010000176.1', 'HG01361.maternal.f1_assembly_v2_genbank.fa', 167193) target region 465 - 166646 len: 166181
# ('HG00621#1#JAHBCD010000124.1', 'HG00621.paternal.f1_assembly_v2_genbank.fa', 4324300) target region 2878911 - 2879684 len: 773
# ('HG02257#1#JAGYVI010000032.1', 'HG02257.paternal.f1_assembly_v2_genbank.fa', 110050687) target region 109488186 - 110050648 len: 562462
# ('HG01243#2#JAHEOX010000004.1', 'HG01243.maternal.f1_assembly_v2_genbank.fa', 37034685) target region 27024144 - 28962523 len: 1938379
# ('HG02818#1#JAHEOS010000025.1', 'HG02818.paternal.f1_assembly_v2_genbank.fa', 11502620) target region 210182 - 408669 len: 198487
# ('HG02486#2#JAGYVL010000101.1', 'HG02486.maternal.f1_assembly_v2_genbank.fa', 8845704) target region 7528971 - 8845351 len: 1316380
# ('HG02818#2#JAHEOR010000140.1', 'HG02818.maternal.f1_assembly_v2_genbank.fa', 4323890) target region 1442742 - 1443515 len: 773
# ('HG00673#2#JAHBBY010000085.1', 'HG00673.maternal.f1_assembly_v2_genbank.fa', 20434620) target region 19588662 - 20433977 len: 845315
# ('HG03516#1#JAGYYT010000286.1', 'HG03516.paternal.f1_assembly_v2_genbank.fa', 75685) target region 127 - 75443 len: 75316
# ('HG00733#1#JAHEPQ010000090.1', 'HG00733.paternal.f1_assembly_v2_genbank.fa', 6963914) target region 6148619 - 6963662 len: 815043
# ('HG02572#2#JAHAOV010000142.1', 'HG02572.maternal.f1_assembly_v2_genbank.fa', 2673346) target region 1001341 - 1002114 len: 773
# ('HG02818#1#JAHEOS010000397.1', 'HG02818.paternal.f1_assembly_v2_genbank.fa', 57588) target region 369 - 56939 len: 56570
# ('NA19240#1#JAHEOM010000077.1', 'NA19240.paternal.f1_assembly_v2_genbank.fa', 9211513) target region 8072506 - 9211160 len: 1138654
# ('HG00735#2#JAHBCG010000038.1', 'HG00735.maternal.f1_assembly_v2_genbank.fa', 31959602) target region 29222983 - 29223756 len: 773
# ('HG01109#2#JAHEOZ010000055.1', 'HG01109.maternal.f1_assembly_v2_genbank.fa', 10860060) target region 7159033 - 7374764 len: 215731
# ('NA20129#2#JAHEPD010000126.1', 'NA20129.maternal.f1_assembly_v2_genbank.fa', 9103430) target region 8070472 - 9102892 len: 1032420
# ('HG00438#2#JAHBCA010000067.1', 'HG00438.maternal.f1_assembly_v2_genbank.fa', 8414389) target region 100 - 882120 len: 882020
# ('HG02145#1#JAHKSG010000022.1', 'HG02145.paternal.f1_assembly_v2_genbank.fa', 25355966) target region 16431058 - 16432279 len: 1221
# ('HG02630#1#JAHAOQ010000326.1', 'HG02630.paternal.f1_assembly_v2_genbank.fa', 67081) target region 384 - 66709 len: 66325
# ('NA18906#2#JAHEON010000026.1', 'NA18906.maternal.f1_assembly_v2_genbank.fa', 5366241) target region 3915843 - 3916616 len: 773
# ('HG00733#1#JAHEPQ010000084.1', 'HG00733.paternal.f1_assembly_v2_genbank.fa', 18668836) target region 810935 - 811708 len: 773
# ('HG02572#2#JAHAOV010000009.1', 'HG02572.maternal.f1_assembly_v2_genbank.fa', 26893122) target region 14005479 - 14160748 len: 155269
# ('HG00741#2#JAHALX010000118.1', 'HG00741.maternal.f1_assembly_v2_genbank.fa', 16604336) target region 118729 - 120749 len: 2020
# ('HG02148#1#JAHAMG010000037.1', 'HG02148.paternal.f1_assembly_v2_genbank.fa', 20171746) target region 2519 - 523824 len: 521305
# ('HG00438#2#JAHBCA010000061.1', 'HG00438.maternal.f1_assembly_v2_genbank.fa', 2347175) target region 901477 - 902250 len: 773
# ('HG00735#1#JAHBCH010000036.1', 'HG00735.paternal.f1_assembly_v2_genbank.fa', 109889325) target region 109455688 - 109888839 len: 433151
# ('HG00621#1#JAHBCD010000230.1', 'HG00621.paternal.f1_assembly_v2_genbank.fa', 34862) target region 141 - 33657 len: 33516
# ('HG01952#2#JAHAMD010000016.1', 'HG01952.maternal.f1_assembly_v2_genbank.fa', 59464697) target region 57869938 - 57870711 len: 773
# ('HG00741#1#JAHALY010000069.1', 'HG00741.paternal.f1_assembly_v2_genbank.fa', 2090472) target region 843255 - 844028 len: 773
# ('HG01175#2#JAHALZ010000034.1', 'HG01175.maternal.f1_assembly_v2_genbank.fa', 21934233) target region 21564188 - 21889092 len: 324904
# ('HG00673#1#JAHBBZ010000094.1', 'HG00673.paternal.f1_assembly_v2_genbank.fa', 27827381) target region 27307341 - 27826605 len: 519264
# ('HG00733#2#JAHEPP010000052.1', 'HG00733.maternal.f1_assembly_v2_genbank.fa', 23839913) target region 23186531 - 23839880 len: 653349
# ('HG02486#1#JAGYVM010000048.1', 'HG02486.paternal.f1_assembly_v2_genbank.fa', 9839476) target region 9630228 - 9631834 len: 1606
# ('HG005#1#JAHEPO010000025.1', 'HG005.paternal.f1_assembly_v2_genbank.fa', 110835687) target region 109484773 - 110834532 len: 1349759
# ('HG02559#1#JAGYVK010000006.1', 'HG02559.paternal.f1_assembly_v2_genbank.fa', 110433957) target region 109462901 - 110433666 len: 970765
# ('HG01978#2#JAGYVR010000081.1', 'HG01978.maternal.f1_assembly_v2_genbank.fa', 20814705) target region 17855603 - 17856376 len: 773
# ('HG00735#2#JAHBCG010000020.1', 'HG00735.maternal.f1_assembly_v2_genbank.fa', 44464270) target region 18298767 - 18299477 len: 710
# ('HG01175#2#JAHALZ010000028.1', 'HG01175.maternal.f1_assembly_v2_genbank.fa', 54189158) target region 53922145 - 54187803 len: 265658
# ('HG02559#1#JAGYVK010000003.1', 'HG02559.paternal.f1_assembly_v2_genbank.fa', 22506429) target region 206622 - 244098 len: 37476
# ('HG03540#2#JAGYVX010000147.1', 'HG03540.maternal.f1_assembly_v2_genbank.fa', 3774226) target region 3484702 - 3486308 len: 1606
# ('NA21309#2#JAHEPB010000186.1', 'NA21309.maternal.f1_assembly_v2_genbank.fa', 3499255) target region 1825795 - 1826568 len: 773
# ('HG02109#1#JAHEPG010000039.1', 'HG02109.paternal.f1_assembly_v2_genbank.fa', 39097705) target region 20989931 - 21692934 len: 703003
# ('HG01361#2#JAGYYW010000016.1', 'HG01361.maternal.f1_assembly_v2_genbank.fa', 43440497) target region 31215787 - 31216294 len: 507
# ('HG00673#1#JAHBBZ010000339.1', 'HG00673.paternal.f1_assembly_v2_genbank.fa', 45722) target region 3739 - 39992 len: 36253
# ('HG03486#1#JAHEOQ010000197.1', 'HG03486.paternal.f1_assembly_v2_genbank.fa', 3404690) target region 1959465 - 1960238 len: 773
# ('HG02080#2#JAHEOV010000003.1', 'HG02080.maternal.f1_assembly_v2_genbank.fa', 11604494) target region 10819509 - 11604247 len: 784738
# ('HG02145#1#JAHKSG010000252.1', 'HG02145.paternal.f1_assembly_v2_genbank.fa', 3245071) target region 1442791 - 1443564 len: 773
# ('HG01106#2#JAHAMB010000206.1', 'HG01106.maternal.f1_assembly_v2_genbank.fa', 83174) target region 533 - 82790 len: 82257
# ('HG01109#2#JAHEOZ010000028.1', 'HG01109.maternal.f1_assembly_v2_genbank.fa', 17927800) target region 5569230 - 5570451 len: 1221
# ('NA20129#2#JAHEPD010000226.1', 'NA20129.maternal.f1_assembly_v2_genbank.fa', 2748044) target region 1297682 - 1298455 len: 773
# ('HG00438#1#JAHBCB010000036.1', 'HG00438.paternal.f1_assembly_v2_genbank.fa', 23921609) target region 2088 - 491537 len: 489449
# ('HG005#1#JAHEPO010000013.1', 'HG005.paternal.f1_assembly_v2_genbank.fa', 23809940) target region 23097829 - 23809574 len: 711745
# ('HG02055#2#JAHEPJ010000041.1', 'HG02055.maternal.f1_assembly_v2_genbank.fa', 31577246) target region 8811989 - 8812496 len: 507
# ('HG01361#2#JAGYYW010000261.1', 'HG01361.maternal.f1_assembly_v2_genbank.fa', 44198) target region 5640 - 43302 len: 37662
# ('HG01123#2#JAGYYY010000036.1', 'HG01123.maternal.f1_assembly_v2_genbank.fa', 50652301) target region 50062194 - 50650634 len: 588440
# ('HG02717#1#JAHAOS010000073.1', 'HG02717.paternal.f1_assembly_v2_genbank.fa', 32364301) target region 31052568 - 31053341 len: 773
# ('HG01978#1#JAGYVS010000070.1', 'HG01978.paternal.f1_assembly_v2_genbank.fa', 26484928) target region 13655041 - 13757881 len: 102840
# ('HG03579#2#JAGYVT010000068.1', 'HG03579.maternal.f1_assembly_v2_genbank.fa', 22034008) target region 13067864 - 13069084 len: 1220
# ('HG01106#1#JAHAMC010000052.1', 'HG01106.paternal.f1_assembly_v2_genbank.fa', 4153349) target region 2708081 - 2708854 len: 773
# ('HG02080#2#JAHEOV010000369.1', 'HG02080.maternal.f1_assembly_v2_genbank.fa', 45518) target region 171 - 44827 len: 44656
# ('HG02818#2#JAHEOR010000098.1', 'HG02818.maternal.f1_assembly_v2_genbank.fa', 10210576) target region 212874 - 469943 len: 257069
# ('HG00735#1#JAHBCH010000009.1', 'HG00735.paternal.f1_assembly_v2_genbank.fa', 20421189) target region 17850915 - 17851688 len: 773
# ('HG02055#2#JAHEPJ010000032.1', 'HG02055.maternal.f1_assembly_v2_genbank.fa', 22511412) target region 21568980 - 22511375 len: 942395
# ('HG02148#1#JAHAMG010000007.1', 'HG02148.paternal.f1_assembly_v2_genbank.fa', 2612241) target region 1446422 - 1447195 len: 773
# ('HG00673#1#JAHBBZ010000070.1', 'HG00673.paternal.f1_assembly_v2_genbank.fa', 21703643) target region 12783231 - 12784456 len: 1225
# ('HG02055#2#JAHEPJ010000029.1', 'HG02055.maternal.f1_assembly_v2_genbank.fa', 8577404) target region 7532679 - 8576128 len: 1043449
# ('NA19240#1#JAHEOM010000035.1', 'NA19240.paternal.f1_assembly_v2_genbank.fa', 5003223) target region 4722618 - 4723328 len: 710
# ('HG01123#1#JAGYYZ010000313.1', 'HG01123.paternal.f1_assembly_v2_genbank.fa', 37315) target region 23722 - 25894 len: 2172
# ('HG02486#1#JAGYVM010000018.1', 'HG02486.paternal.f1_assembly_v2_genbank.fa', 160280861) target region 109434771 - 111182390 len: 1747619
# ('HG01123#1#JAGYYZ010000310.1', 'HG01123.paternal.f1_assembly_v2_genbank.fa', 80662) target region 15393 - 15900 len: 507
# ('HG01123#2#JAGYYY010000145.1', 'HG01123.maternal.f1_assembly_v2_genbank.fa', 662996) target region 492 - 662892 len: 662400
# ('HG03486#1#JAHEOQ010000046.1', 'HG03486.paternal.f1_assembly_v2_genbank.fa', 36676772) target region 27082108 - 27093946 len: 11838
# ('HG00733#2#JAHEPP010000397.1', 'HG00733.maternal.f1_assembly_v2_genbank.fa', 191356) target region 351 - 190759 len: 190408
# ('HG01361#1#JAGYYX010000199.1', 'HG01361.paternal.f1_assembly_v2_genbank.fa', 85219) target region 531 - 83169 len: 82638
# ('HG02559#2#JAGYVJ010000051.1', 'HG02559.maternal.f1_assembly_v2_genbank.fa', 31057066) target region 14173460 - 14175481 len: 2021
# ('HG02630#2#JAHAOP010000146.1', 'HG02630.maternal.f1_assembly_v2_genbank.fa', 223038) target region 252 - 222935 len: 222683
# ('NA20129#1#JAHEPE010000259.1', 'NA20129.paternal.f1_assembly_v2_genbank.fa', 422690) target region 91780 - 422434 len: 330654
# ('HG01258#2#JAGYYU010000046.1', 'HG01258.maternal.f1_assembly_v2_genbank.fa', 47063220) target region 22397949 - 22398659 len: 710
# ('HG01928#1#JAGYVQ010000040.1', 'HG01928.paternal.f1_assembly_v2_genbank.fa', 18380701) target region 42454 - 258100 len: 215646
# ('HG01978#2#JAGYVR010000045.1', 'HG01978.maternal.f1_assembly_v2_genbank.fa', 12819844) target region 711808 - 712518 len: 710
# ('NA19240#1#JAHEOM010000023.1', 'NA19240.paternal.f1_assembly_v2_genbank.fa', 39406010) target region 27448142 - 27448795 len: 653
# ('HG03486#2#JAHEOP010000142.1', 'HG03486.maternal.f1_assembly_v2_genbank.fa', 3234946) target region 1789871 - 1790644 len: 773
# ('HG02572#1#JAHAOW010000085.1', 'HG02572.paternal.f1_assembly_v2_genbank.fa', 12792151) target region 12089956 - 12791498 len: 701542
# ('HG01978#1#JAGYVS010000049.1', 'HG01978.paternal.f1_assembly_v2_genbank.fa', 29582006) target region 7531088 - 9867917 len: 2336829
# ('HG01109#2#JAHEOZ010000001.1', 'HG01109.maternal.f1_assembly_v2_genbank.fa', 35424037) target region 2724346 - 2725119 len: 773
# ('HG01109#2#JAHEOZ010000379.1', 'HG01109.maternal.f1_assembly_v2_genbank.fa', 21018) target region 159 - 19936 len: 19777
# ('HG02886#2#JAHAOT010000279.1', 'HG02886.maternal.f1_assembly_v2_genbank.fa', 358660) target region 2279 - 358517 len: 356238
# ('HG01358#2#JAGYZA010000002.1', 'HG01358.maternal.f1_assembly_v2_genbank.fa', 123863604) target region 102726134 - 104183621 len: 1457487
# ('HG02717#1#JAHAOS010000049.1', 'HG02717.paternal.f1_assembly_v2_genbank.fa', 25119863) target region 12381076 - 12383096 len: 2020
# ('HG01258#2#JAGYYU010000167.1', 'HG01258.maternal.f1_assembly_v2_genbank.fa', 660585) target region 111 - 660554 len: 660443
# ('HG01891#1#JAGYVO010000200.1', 'HG01891.paternal.f1_assembly_v2_genbank.fa', 80307) target region 448 - 79972 len: 79524
# ('chr5_hg38', 'hg38_tagged.fa', 181538259) target region 21297793 - 22176574 len: 878781
# ('HG03540#2#JAGYVX010000232.1', 'HG03540.maternal.f1_assembly_v2_genbank.fa', 397588) target region 123 - 397321 len: 397198
# ('HG00735#2#JAHBCG010000102.1', 'HG00735.maternal.f1_assembly_v2_genbank.fa', 1028481) target region 491 - 1028455 len: 1027964
# ('HG02886#2#JAHAOT010000019.1', 'HG02886.maternal.f1_assembly_v2_genbank.fa', 27249631) target region 26289763 - 27248537 len: 958774
# ('HG01258#1#JAGYYV010000066.1', 'HG01258.paternal.f1_assembly_v2_genbank.fa', 40483040) target region 2354547 - 2355320 len: 773
# ('HG00621#2#JAHBCC010000051.1', 'HG00621.maternal.f1_assembly_v2_genbank.fa', 43219406) target region 8871517 - 8873538 len: 2021
# ('HG00733#2#JAHEPP010000128.1', 'HG00733.maternal.f1_assembly_v2_genbank.fa', 84004) target region 439 - 83711 len: 83272
# ('NA18906#2#JAHEON010000090.1', 'NA18906.maternal.f1_assembly_v2_genbank.fa', 5876144) target region 2187893 - 2386396 len: 198503
# ('HG01361#1#JAGYYX010000181.1', 'HG01361.paternal.f1_assembly_v2_genbank.fa', 68946) target region 538 - 68632 len: 68094
# ('HG01891#1#JAGYVO010000191.1', 'HG01891.paternal.f1_assembly_v2_genbank.fa', 528562) target region 2075 - 528176 len: 526101
# ('HG02486#2#JAGYVL010000026.1', 'HG02486.maternal.f1_assembly_v2_genbank.fa', 60776310) target region 57728737 - 57729510 len: 773
# ('HG01358#1#JAGYZB010000031.1', 'HG01358.paternal.f1_assembly_v2_genbank.fa', 36233131) target region 20912953 - 22625923 len: 1712970
# ('HG03098#2#JAHEPL010000053.1', 'HG03098.maternal.f1_assembly_v2_genbank.fa', 23670007) target region 22966577 - 23669698 len: 703121
# ('HG00735#2#JAHBCG010000090.1', 'HG00735.maternal.f1_assembly_v2_genbank.fa', 24172404) target region 23672990 - 24172185 len: 499195
# ('HG02622#1#JAHAOO010000014.1', 'HG02622.paternal.f1_assembly_v2_genbank.fa', 103756111) target region 1067 - 702172 len: 701105
# ('HG02080#2#JAHEOV010000330.1', 'HG02080.maternal.f1_assembly_v2_genbank.fa', 180149) target region 44874 - 179519 len: 134645
# ('HG02622#2#JAHAON010000179.1', 'HG02622.maternal.f1_assembly_v2_genbank.fa', 117621) target region 256 - 117110 len: 116854
# ('NA21309#2#JAHEPB010000005.1', 'NA21309.maternal.f1_assembly_v2_genbank.fa', 21739749) target region 20702244 - 21739383 len: 1037139
# ('chr5_hg19', 'hg19_tagged.fa', 180915260) target region 21297902 - 22176683 len: 878781
# ('NA18906#1#JAHEOO010000061.1', 'NA18906.paternal.f1_assembly_v2_genbank.fa', 52085021) target region 35578019 - 35695551 len: 117532
# ('HG00735#2#JAHBCG010000087.1', 'HG00735.maternal.f1_assembly_v2_genbank.fa', 8146014) target region 7535484 - 8145627 len: 610143
# ('HG00673#1#JAHBBZ010000158.1', 'HG00673.paternal.f1_assembly_v2_genbank.fa', 11728702) target region 208 - 897742 len: 897534
# ('HG02886#1#JAHAOU010000426.1', 'HG02886.paternal.f1_assembly_v2_genbank.fa', 26826) target region 4898 - 26683 len: 21785
# ('HG01952#2#JAHAMD010000074.1', 'HG01952.maternal.f1_assembly_v2_genbank.fa', 3519956) target region 30104 - 31710 len: 1606
# ('HG03098#1#JAHEPM010000094.1', 'HG03098.paternal.f1_assembly_v2_genbank.fa', 31475627) target region 22622829 - 22624049 len: 1220
# ('HG00438#2#JAHBCA010000116.1', 'HG00438.maternal.f1_assembly_v2_genbank.fa', 575484) target region 568 - 574743 len: 574175
# ('HG02886#2#JAHAOT010000128.1', 'HG02886.maternal.f1_assembly_v2_genbank.fa', 12043220) target region 11419793 - 11805679 len: 385886
# ('NA18906#2#JAHEON010000075.1', 'NA18906.maternal.f1_assembly_v2_genbank.fa', 25971134) target region 10556269 - 10720441 len: 164172
# ('HG01258#2#JAGYYU010000016.1', 'HG01258.maternal.f1_assembly_v2_genbank.fa', 103697679) target region 352 - 552644 len: 552292
# ('HG00733#1#JAHEPQ010000511.1', 'HG00733.paternal.f1_assembly_v2_genbank.fa', 33328) target region 452 - 32137 len: 31685
# ('HG01891#2#JAGYVN010000002.1', 'HG01891.maternal.f1_assembly_v2_genbank.fa', 110625089) target region 109457446 - 110624891 len: 1167445
# ('HG01123#1#JAGYYZ010000020.1', 'HG01123.paternal.f1_assembly_v2_genbank.fa', 103978760) target region 202 - 828339 len: 828137
# ('HG01123#1#JAGYYZ010000398.1', 'HG01123.paternal.f1_assembly_v2_genbank.fa', 16040) target region 247 - 14125 len: 13878
# ('HG02572#2#JAHAOV010000182.1', 'HG02572.maternal.f1_assembly_v2_genbank.fa', 3748495) target region 40573 - 257388 len: 216815
# ('HG01243#2#JAHEOX010000035.1', 'HG01243.maternal.f1_assembly_v2_genbank.fa', 31384221) target region 10500012 - 10500722 len: 710
# ('HG01106#2#JAHAMB010000019.1', 'HG01106.maternal.f1_assembly_v2_genbank.fa', 123902156) target region 91204137 - 91204910 len: 773
# ('HG01109#2#JAHEOZ010000092.1', 'HG01109.maternal.f1_assembly_v2_genbank.fa', 50968056) target region 26596468 - 28461521 len: 1865053
# ('HG03579#1#JAGYVU010000060.1', 'HG03579.paternal.f1_assembly_v2_genbank.fa', 2545229) target region 1446373 - 1447146 len: 773
# ('HG02055#1#JAHEPK010000050.1', 'HG02055.paternal.f1_assembly_v2_genbank.fa', 21160270) target region 1560 - 447293 len: 445733
# ('HG02630#1#JAHAOQ010000112.1', 'HG02630.paternal.f1_assembly_v2_genbank.fa', 5090036) target region 1673118 - 1673891 len: 773
# ('HG02080#1#JAHEOW010000395.1', 'HG02080.paternal.f1_assembly_v2_genbank.fa', 60294) target region 85 - 59664 len: 59579
# ('HG03486#1#JAHEOQ010000379.1', 'HG03486.paternal.f1_assembly_v2_genbank.fa', 24651) target region 420 - 22003 len: 21583
# ('HG02257#1#JAGYVI010000054.1', 'HG02257.paternal.f1_assembly_v2_genbank.fa', 57982120) target region 9565042 - 10444777 len: 879735
# ('HG02145#2#JAHKSF010000115.1', 'HG02145.maternal.f1_assembly_v2_genbank.fa', 13641345) target region 10825871 - 12976594 len: 2150723
# ('HG02818#2#JAHEOR010000543.1', 'HG02818.maternal.f1_assembly_v2_genbank.fa', 72211) target region 486 - 71820 len: 71334
# ('HG03516#2#JAGYYS010000005.1', 'HG03516.maternal.f1_assembly_v2_genbank.fa', 73727345) target region 423 - 1385036 len: 1384613
# ('HG01243#1#JAHEOY010000059.1', 'HG01243.paternal.f1_assembly_v2_genbank.fa', 27849187) target region 26611476 - 27849080 len: 1237604
# ('HG01071#1#JAHBCF010000089.1', 'HG01071.paternal.f1_assembly_v2_genbank.fa', 16561671) target region 97435 - 99456 len: 2021
# ('HG02148#2#JAHAMF010000370.1', 'HG02148.maternal.f1_assembly_v2_genbank.fa', 35441) target region 473 - 34371 len: 33898
# ('HG03540#1#JAGYVY010000012.1', 'HG03540.paternal.f1_assembly_v2_genbank.fa', 11845403) target region 10818375 - 11842123 len: 1023748
# ('HG01175#1#JAHAMA010000010.1', 'HG01175.paternal.f1_assembly_v2_genbank.fa', 126766583) target region 21482762 - 23635646 len: 2152884
# ('chr6_chm13', 'chm13_tagged.fa', 172126628) target region 57610262 - 57611035 len: 773
# ('chr5_KI270897v1_alt_hg38', 'hg38_tagged.fa', 1144418) target region 369 - 1144107 len: 1143738
# ('HG00621#2#JAHBCC010000015.1', 'HG00621.maternal.f1_assembly_v2_genbank.fa', 27163080) target region 26699765 - 27163038 len: 463273
# ('HG02148#1#JAHAMG010000071.1', 'HG02148.paternal.f1_assembly_v2_genbank.fa', 42541387) target region 12193303 - 12377983 len: 184680
# ('HG00673#2#JAHBBY010000231.1', 'HG00673.maternal.f1_assembly_v2_genbank.fa', 557820) target region 356 - 557606 len: 557250
# ('HG02630#1#JAHAOQ010000103.1', 'HG02630.paternal.f1_assembly_v2_genbank.fa', 31296134) target region 4403799 - 4404509 len: 710
# ('HG02080#1#JAHEOW010000008.1', 'HG02080.paternal.f1_assembly_v2_genbank.fa', 11488533) target region 10820391 - 11488220 len: 667829
# ('HG02148#2#JAHAMF010000367.1', 'HG02148.maternal.f1_assembly_v2_genbank.fa', 50829) target region 590 - 50433 len: 49843
# ('HG01175#1#JAHAMA010000007.1', 'HG01175.paternal.f1_assembly_v2_genbank.fa', 19512731) target region 10569799 - 10570572 len: 773
# ('HG01978#2#JAGYVR010000245.1', 'HG01978.maternal.f1_assembly_v2_genbank.fa', 34397) target region 105 - 34277 len: 34172
# ('HG02257#1#JAGYVI010000169.1', 'HG02257.paternal.f1_assembly_v2_genbank.fa', 462950) target region 707 - 462312 len: 461605
# ('NA21309#1#JAHEPC010000103.1', 'NA21309.paternal.f1_assembly_v2_genbank.fa', 8203736) target region 457 - 131622 len: 131165
# ('NA18906#2#JAHEON010000175.1', 'NA18906.maternal.f1_assembly_v2_genbank.fa', 650545) target region 1432 - 647651 len: 646219
# ('NA18906#2#JAHEON010000048.1', 'NA18906.maternal.f1_assembly_v2_genbank.fa', 23198597) target region 22768311 - 23193623 len: 425312
# ('HG005#1#JAHEPO010000059.1', 'HG005.paternal.f1_assembly_v2_genbank.fa', 46572731) target region 25861856 - 25862296 len: 440
# ('HG02257#2#JAGYVH010000080.1', 'HG02257.maternal.f1_assembly_v2_genbank.fa', 32276632) target region 31003904 - 31004677 len: 773
# ('HG03453#1#JAGYVW010000063.1', 'HG03453.paternal.f1_assembly_v2_genbank.fa', 25347133) target region 8778194 - 8778847 len: 653
# ('HG002#1#JAHKSE010000318.1', 'HG002.paternal.f1_assembly_v2_genbank.fa', 19191) target region 1439 - 18915 len: 17476
# ('HG01952#2#JAHAMD010000038.1', 'HG01952.maternal.f1_assembly_v2_genbank.fa', 104831513) target region 103122595 - 104831279 len: 1708684
# ('HG02148#1#JAHAMG010000056.1', 'HG02148.paternal.f1_assembly_v2_genbank.fa', 71128951) target region 69589718 - 71128839 len: 1539121

# %%
plt.hist(rgn_lengths, bins=32);
plt.xlabel("ROI region size")
plt.ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
# Some mapped regions are larger, let's check the repeat / CNV by quick dot plots. We label the region of the ROI by two vertical grey lines. We observe that there are different number of intersections (~different copy number) of the region the "dots" due to the different repeat structures.

# %%
seq_list = []
i = 1
plt.figure(figsize=(24, 24))
for k in list(aln_range.keys()):
    ctg_name, source, _ = sdb.seq_info[k]
    seq_id = k
    rgns = aln_range[k].copy()

    rgns = pgrtk.merge_regions(rgns, tol=1000)

    for rgn in rgns:
        b, e, length, orientation, aln = rgn
        aln.sort()
  
        if aln[0][0][0] > padding or aln[-1][0][1] < padding + roi_len:
            continue
        
        #for illustration purpose, we only plot with the sequnce spanned through the whole region

        if e-b < 0.5 * (roi_len + 2 * padding):             
            continue

        seq =  sdb.get_sub_seq(source, ctg_name, b, e)
  
        if orientation == 1:
            seq = pgrtk.rc_byte_seq(seq)

        seq_list.append(("{}_{}_{}_{}".format(ctg_name, b, e, orientation), seq))
        x, y = pgrtk.get_shmmr_dots(roi_seq, seq, 32, 32, 12, 1)
        
        
        if i <= 36:
            plt.subplot(6,6,i)
            plt.plot(x, y, ".", markersize=0.1)
            plt.plot([padding, padding],[0, max(y)], color='grey')
            plt.plot([padding+roi_len, padding+roi_len],[0, max(y)], color='grey')
        i += 1

# %% [markdown]
# ## Create a new shimmer database for the detailed study

# %%
seq_list = []
seq_info = sdb.seq_info.copy()
i = 0
for k in list(aln_range.keys()):
    ctg_name, source, _ = seq_info[k]
    seq_id = k
    rgns = aln_range[k].copy()
    
    rgns = pgrtk.merge_regions(rgns,tol=1000)

    for rgn in rgns:
        b, e, length, orientation, aln = rgn
        
        #for illustration purpose, we only plot with the sequnce spanned through the whole region

        if e-b < 0.75 * (roi_len + 2 * padding):             
            continue
            
        seq =  sdb.get_sub_seq(source, ctg_name, b, e)
        if orientation == 1:
            seq = pgrtk.rc_byte_seq(seq)
  
        seq_list.append(("{}_{}_{}_{}".format(ctg_name, b, e, orientation), seq))
        
        i += 1

# %% [markdown]
# Create a shimmer indext database with smaller window (denser shimmers)

# %%
new_sdb = pgrtk.SeqIndexDB() 
new_sdb.load_from_seq_list(seq_list, w=128, k=56, r=12, min_span=28)

# %%
len(new_sdb.seq_info)
# Out:
# 31

# %%
#find hits in the pangenomic reference
aln_range0 = pgrtk.query_sdb(new_sdb, roi_seq, merge_range_tol=300000)

aln_range = aln_range0

print("The number of hits is", len(aln_range))

count = 0
for sid, rgns in aln_range.items():
    count += len(rgns)

print("The total aligned regions is", count)
# Out:
# The number of hits is 31
# The total aligned regions is 36

# %% [markdown]
# Let's loop through the hits (contigs that has alignments) and see the number of "copies".

# %%
from collections import Counter

# %%
n_copy = {}
for k in list(aln_range.keys()):
    n_copy[k] = len(aln_range[k])
copy_count = Counter(n_copy.values())
for nc, nh in copy_count.items():
    print("number of copy: {}, number of haplotypes: {}".format(nc, nh))
# Out:
# number of copy: 1, number of haplotypes: 27
# number of copy: 3, number of haplotypes: 1
# number of copy: 2, number of haplotypes: 3

# %%
rgn_lengths = []
for k in list(aln_range.keys()):
    for sid, rgns in aln_range.items():
        for rgn in rgns:
            b, e = rgn[0:2]
            #print(seq_index[k], "target region", b, "-", e, "len:", e-b )
            rgn_lengths.append(e-b)
plt.hist(rgn_lengths, bins=32);
plt.xlabel("ROI size")
plt.ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %%
f0 = open("/results/SMN1_SMN2_region_seq.fa", "w")
for ctg, seq in seq_list:
    
    print(">{}".format(ctg), file=f0)
    print(pgrtk.u8_to_string(seq), file=f0)
       
f0.close()

# %%
help(new_sdb.generate_mapg_gfa)
# Out:
# Help on built-in function generate_mapg_gfa:
#
# generate_mapg_gfa(...) method of builtins.SeqIndexDB instance
#     Convert the adjecent list of the shimmer graph shimmer_pair -> GFA
#
#     Parameters
#     ----------
#     min_count : int
#         the minimum number of times a pair of shimmers must be observed to be included in the graph
#
#     filenpath : string
#         the path to the output file
#
#     Returns
#     -------
#
#     None
#         The data is written into the file at filepath

# %%
new_sdb = pgrtk.SeqIndexDB() 
new_sdb.load_from_seq_list(seq_list, w=128, k=56, r=12, min_span=28)
new_sdb.generate_mapg_gfa(0, "/results/SMN1_SMN2_128_56_12_28.gfa")
new_sdb.write_mapg_idx("/results/SMN1_SMN2_region_128_56_12_28.gidx")


new_sdb = pgrtk.SeqIndexDB() 
new_sdb.load_from_seq_list(seq_list, w=128, k=56, r=2, min_span=28)
new_sdb.generate_mapg_gfa(0, "/results/SMN1_SMN2_128_56_2_28.gfa")
new_sdb.write_mapg_idx("/results/SMN1_SMN2_region_128_56_2_28.gidx")

# %% [markdown]
# ## Construct the genome graphs

# %%
import networkx as nx
from networkx.drawing import nx_pydot

# %%
def get_graph(seq_list, w=128, k=56, r=4, min_span=28, highlite=0):
    new_sdb = pgrtk.SeqIndexDB() 
    new_sdb.load_from_seq_list(seq_list, w=w, k=k, r=r, min_span=min_span)
    new_sdb.generate_mapg_gfa(0, f"/results/{name}-{w}-{k}-{r}.gfa")
    sid_to_path = {}
    spl=new_sdb.get_shmmr_pair_list()
    for (k0, k1, sid, p0, p1, o) in spl:
        sid_to_path.setdefault(sid,[])
        sid_to_path[sid].append((p0, p1, o, k0, k1))
    G = nx.DiGraph()
    m = new_sdb.get_shmmr_map()
    for sid, path in sid_to_path.items():
        #print(sid)
        path.sort()
        v = path[0]
        #if sid != 45:
        #    continue
        for w in path[1:]:
            v = tuple(v[-2:])
            w = tuple(w[-2:])
            color = "yellow"
            penwidth =  2 + 0.1 * (len(m[v]) * len(m[w])) ** 0.5
            G.add_edge(v, w, penwidth = penwidth, color="orange" )
            G.add_edge(w, v, penwidth = penwidth, color="orange" )
            G.add_node(v, fillcolor=color, style="filled")
            #G.add_node(w, size =  len(m[v]))
            v = w
            
    node_to_sid = {}
    for v in G.nodes():
        node_to_sid.setdefault(v, {})
        for sid, path in sid_to_path.items():
            node_to_sid[v][sid] = 0
            
     
    for sid, path in sid_to_path.items():
        #print(sid)
        path.sort()
        for v in path:
            v = tuple(v[-2:])
            node_to_sid[v][sid] = 1
    #nx.set_node_attributes(G, node_to_sid)  
    return G

# %%
def get_graph2(seq_list, w=128, k=56, r=4, min_span=28, highlite=0):
    new_sdb = pgrtk.SeqIndexDB() 
    new_sdb.load_from_seq_list(seq_list, w=w, k=k, r=r, min_span=min_span)
    new_sdb.generate_mapg_gfa(0, f"/results/{name}-{w}-{k}-{r}.gfa")
    sid_to_path = {}
    spl=new_sdb.get_shmmr_pair_list()
    for (k0, k1, sid, p0, p1, o) in spl:
        sid_to_path.setdefault(sid,[])
        sid_to_path[sid].append((p0, p1, o, k0, k1))
    G = nx.DiGraph()
    m = new_sdb.get_shmmr_map()
    for sid, path in sid_to_path.items():
        #print(sid)
        path.sort()
        v = path[0]
        #if sid != 45:
        #    continue
        for w in path[1:]:
            v = tuple(v[-2:])
            w = tuple(w[-2:])
            color = "yellow"
            penwidth =  1 + 0.02 * (len(m[v]) * len(m[w])) ** 0.5
            G.add_edge(v, w, penwidth = penwidth, color="orange" )
            G.add_edge(w, v, penwidth = penwidth, color="orange" )
            G.add_node(v, fillcolor=color, style="filled")
            #G.add_node(w, size =  len(m[v]))
            v = w
            
    for sid, path in sid_to_path.items():
        #print(sid)
        path.sort()
        v = path[0]
        if sid != highlite:
            continue
        for w in path[1:]:
            v = tuple(v[-2:])
            w = tuple(w[-2:])
            color = "blue"
            penwidth =  1 + 0.02 * (len(m[v]) * len(m[w])) ** 0.5
            G.add_node(v, fillcolor=color, style="filled")
            G.add_edge(v, w, penwidth = penwidth, color=color )
            G.add_edge(w, v, penwidth = penwidth, color=color )
            v = w
    return G

# %% [raw]
# for r in (12,4):
#     w=80; k=56;
#     name="ROI"
#     G = get_graph2(seq_list, w=w, k=k, r=r, highlite=0)
#
#     #nx.write_gexf(G, f"/results/{name}-{w}-{k}-{r}.gexf")
#     nx_pydot.write_dot(G, f"{name}-{w}-{k}-{r}.dot")
#     ## for this version of graphviz, we need to create PDF to get the bounding box right
#     os.system(f"""neato -Tpdf {name}-{w}-{k}-{r}.dot -x -Grankdir=LR -Gsize=64,64 \
#     -Nfixedsize=true -Nwidth=.5 -Nheight=.5 -Nlabel="" > {name}-{w}-{k}-{r}.pdf""")
#     os.system(f"""pdf2svg {name}-{w}-{k}-{r}.pdf {name}-{w}-{k}-{r}.svg""")

# %% [raw]
# for ht in range(0,12):
#     w=80; k=56; r=6;
#     name="ROI"
#     G = get_graph2(seq_list, w=w, k=k, r=r, highlite=ht)
#
#     #nx.write_gexf(G, f"/results/{name}-{w}-{k}-{r}.gexf")
#     nx_pydot.write_dot(G, f"{name}-{w}-{k}-{r}-h{ht}.dot")
#     ## for this version of graphviz, we need to create PDF to get the bounding box right
#     os.system(f"""neato -Tpdf {name}-{w}-{k}-{r}-h{ht}.dot -x -Grankdir=LR -Gsize=64,64 \
#     -Nfixedsize=true -Nwidth=.5 -Nheight=.5 -Nlabel="" > {name}-{w}-{k}-{r}-h{ht}.pdf""")
#     os.system(f"""pdf2svg {name}-{w}-{k}-{r}-h{ht}.pdf {name}-{w}-{k}-{r}-h{ht}.svg""")

# %% [markdown]
# ## Generate Repeat Pattern Using the Principal Bundles

# %%
len(seq_list)
# Out:
# 31

# %%
import numpy as np

# %%
shmmrspec = {"w": 80, "k":56, "r":6, "min_span":28 }
new_sdb = pgrtk.SeqIndexDB() 
new_sdb.load_from_seq_list(seq_list, 
                           w = shmmrspec["w"], 
                           k = shmmrspec["k"], 
                           r = shmmrspec["r"], 
                           min_span = shmmrspec["min_span"])

# %%
principal_bundles, sid_smps = new_sdb.get_principal_bundle_decomposition(0,8)
sid_to_smps = dict(sid_smps)
print(len(principal_bundles))
# Out:
# 78

# %%
import numpy as np
from matplotlib import cm

# %%
cmap=plt.get_cmap("nipy_spectral")
cmap

# %%
lpb = len(principal_bundles)
color_theme0 = cmap(np.linspace(0.1, 0.9, lpb))
#pseudo-randomize the colors
idx = np.array([_ * (lpb+8011) for _ in range(lpb)]) % lpb
print(idx)
color_theme = color_theme0[idx]
# Out:
# [ 0 55 32  9 64 41 18 73 50 27  4 59 36 13 68 45 22 77 54 31  8 63 40 17
#  72 49 26  3 58 35 12 67 44 21 76 53 30  7 62 39 16 71 48 25  2 57 34 11
#  66 43 20 75 52 29  6 61 38 15 70 47 24  1 56 33 10 65 42 19 74 51 28  5
#  60 37 14 69 46 23]

# %%
new_sdb.generate_mapg_gfa(0, "/results/test_48_56_4_28.gfa")

v_to_name = {}
with open("/results/test_48_56_4_28.gfa") as f:
    for r in f:
        r = r.strip().split("\t")
        if r[0] != "S":
            continue
        n = r[1]
        v = r[4].split(":")[-1]
        v_to_name[v] = n

f = open("/results/test_48_56_4_28_color.csv", "w")
print("Name,Color", file=f)
for bundle_id, bundle in enumerate(principal_bundles):
    for v in bundle[2]:
        vertex = tuple(v[:2])
        color = color_theme[bundle_id]
  
        print(v_to_name["{:016x}_{:016x}".format(*vertex)], color, file=f, sep=",")
f.close()

# %%
b_vertex_to_position = {}
i = 0
for bundle in principal_bundles:
    for v in bundle[2]:
        vertex = tuple(v[:2])
        b_vertex_to_position[vertex] = i, bundle[0]
        i += 1

# %%
seq_info = new_sdb.seq_info.copy()
sinfo = list(seq_info.items())
sinfo.sort(key=lambda x: x[1][0])

#fig = plt.figure(figsize=(24,96))
pidx = 1
for sid, data in sinfo[:10]:
    ctg, _, _ = data
    smps = sid_to_smps[sid]
    #print(seq_info[sid])
    #print(sid, len(smps))
    x, rx = [], []
    y, ry = [], []
    c, rc = [], []
    for s in smps:
        if s[1] is None:
            continue
        vertex = tuple(s[0][:2])
        x.append(s[0][2])
        y.append(b_vertex_to_position[vertex][0]) # same direction
        c.append(color_theme[s[1][0]])
            

    fig = plt.figure(figsize=(6,2))
    plt.scatter(x, y, marker=".", color=c, s=40)
    
    
    plt.xlim(-10000,2500000)
    plt.title(ctg)

# %%
ref_file_name, SMN1_chr, SMN1_b, SMN1_e = \
('hg38_tagged.fa', 
'chr5_hg38', 
70925087, 70953015)
padding = 100
SMN1_seq = ref_db.get_sub_seq(ref_file_name, SMN1_chr, SMN1_b-padding, SMN1_e+padding)

ref_file_name, SMN2_chr, SMN2_b, SMN2_e = \
('hg38_tagged.fa', 
'chr5_hg38', 
70049669, 70077595)
padding = 100
SMN2_seq = ref_db.get_sub_seq(ref_file_name, SMN2_chr, SMN2_b-padding, SMN2_e+padding)

# %%
gene_matches1 = new_sdb.get_match_positions_with_fragment(SMN1_seq)
gene_matches2 = new_sdb.get_match_positions_with_fragment(SMN2_seq)
gene_matches = [gene_matches1, gene_matches2]

# %%
seq_info = new_sdb.seq_info.copy()
sinfo = list(seq_info.items())
sinfo.sort(key=lambda x: x[1][0])

fig = plt.figure(figsize=(24,64))
pidx = 1
ctg_labels = []
full_length_sids = set()
for sid, data in sinfo:
    
    ctg, _, slen = data
    ctg_labels.append(ctg)
    if slen < 600000:
        continue
    full_length_sids.add(sid)
    smps = sid_to_smps[sid]
    
    #print(seq_info[sid])
    #print(sid, len(smps))
    x, rx = [], []
    y, ry = [], []
    c, rc = [], []

   
    for s in smps:
        if s[1] is None:
            continue
        
        if s[0][4] == s[1][1]:
            x.append(s[0][2])
            y.append(0) # same direction
            c.append(color_theme[s[1][0]])
        else:
            rx.append(s[0][2])
            ry.append(6)
            rc.append(color_theme[s[1][0]])

            
    y = np.array(y) 
    ry = np.array(ry)
    x.reverse()
    c.reverse()
    
    plt.subplot(len(sid_smps), 1, pidx)

    pidx += 1
    plt.scatter(x, y, marker=">", color=c, s=80)
    plt.scatter(rx, ry, marker="<", color=rc, s=80)
    
    for mi in range(len(gene_matches)):
        matches = set([(_[0], _[1]) for _ in gene_matches[mi][sid]])
        track_x = [_[0] for _ in matches]
        plt.scatter(track_x, [-4-mi*2]*len(track_x), marker="s", color="black", s=2)
    
    #plt.axis("off")
    plt.ylim(-14,10)
    plt.xlim(-10000,2500000)
    plt.text(0, -12, ctg, fontsize=18)
