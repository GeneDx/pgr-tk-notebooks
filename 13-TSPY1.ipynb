# %% [markdown]
# ## Install the PGR-TK package

# %% [markdown]
# If neccessary, install the package into your python environment. For example,
# ```
# pip install --force /code/pgrtk-0.3.3-cp38-cp38-linux_x86_64.whl
# ```

# %%
import pgrtk
import os
import matplotlib.pyplot as plt
from IPython.display import SVG
# %matplotlib inline

# %%
pgrtk.__version__
# Out:
# 'pgrtk 0.3.3 (v0.3.3_dev:675e3c7, release build, linux [x86_64] [rustc 1.62.0 (a8314ef7d 2022-06-27)])'

# %%
os.chdir("/results")

# %% [markdown]
# ## Lazy load the the AGCfile for fetching sequences

# %%
ref_db =pgrtk.AGCFile("/data/pgr-tk-HGRP-y1-evaluation-set-v0.agc") # lazy load an agc file of the reference without any SHIMMER index

# %% [markdown]
# ## Load the index into memory
# The loads the index into the memory. It takes about one minute.

# %%
# %%time
sdb = pgrtk.SeqIndexDB()
sdb.load_from_agc_index("/data/pgr-tk-HGRP-y1-evaluation-set-v0")
# Out:
# CPU times: user 19.4 s, sys: 1min 2s, total: 1min 21s
# Wall time: 37.7 s

# %% [markdown]
# We can see the specification about how SHIMMERs are computed using the `get_shmmr_spec()` method.

# %%
sdb.get_shmmr_spec() # window_size, k_mer_size, hieraical_reduction_factor, min_span, use_k_mer_sketch_other_than_minimizer
# Out:
# (80, 56, 4, 64, False)

# %% [markdown]
# ## Query the database with the sequence of the region

# %%
ref_file_name, roi_chr, roi_b, roi_e = 'chm13_tagged.fa', 'chrY_chm13', 8900000, 9900000

#ref_file_name, roi_chr, roi_b, roi_e = 'hg38_tagged.fa', 'chrY_hg38', 9464955, 9471749

padding = 10000
roi_len = roi_e - roi_b
#get a segment of a reference
roi_seq = ref_db.get_sub_seq(ref_file_name, roi_chr, roi_b-padding, roi_e+padding)
x, y = pgrtk.get_shmmr_dots(roi_seq, roi_seq, 32, 32, 12, 2)
plt.plot(x, y, ".", markersize=0.5)
print(x[0])
plt.xlim(0,len(roi_seq))
plt.ylim(0,len(roi_seq))
# Out:
# 1193
# (0.0, 1020000.0)

# %%
#find hits in the pangenomic reference
aln_range = pgrtk.query_sdb(sdb, roi_seq, merge_range_tol=1000000)

print("The number of hits is", len(aln_range))

count = 0
for sid, rgns in aln_range.items():
    count += len(rgns)

print("The total aligned regions is", count)
# Out:
# The number of hits is 28
# The total aligned regions is 35

# %% [markdown]
# We can examine, the target region sizes.

# %%
rgn_lengths = []
for k in list(aln_range.keys()):
    b, e = aln_range[k][0][0:2]
    print(sdb.seq_info[k], "target region", b, "-", e, "len:", e-b )
    rgn_lengths.append(e-b)
# Out:
# ('HG01243#1#JAHEOY010000035.1', 'HG01243.paternal.f1_assembly_v2_genbank.fa', 6702170) target region 2216015 - 2226245 len: 10230
# ('HG002#1#JAHKSE010000282.1', 'HG002.paternal.f1_assembly_v2_genbank.fa', 58205) target region 422 - 57888 len: 57466
# ('chrY_hg38', 'hg38_tagged.fa', 57227415) target region 6246581 - 6266132 len: 19551
# ('HG03492#1#JAHEPI010000037.1', 'HG03492.paternal.f1_assembly_v2_genbank.fa', 5169531) target region 873719 - 1841980 len: 968261
# ('chrY_hg19', 'hg19_tagged.fa', 59373566) target region 6114622 - 6134173 len: 19551
# ('HG00673#1#JAHBBZ010000132.1', 'HG00673.paternal.f1_assembly_v2_genbank.fa', 8881715) target region 7348490 - 8479055 len: 1130565
# ('HG03579#1#JAGYVU010000146.1', 'HG03579.paternal.f1_assembly_v2_genbank.fa', 8420658) target region 363595 - 1425709 len: 1062114
# ('HG02717#1#JAHAOS010000087.1', 'HG02717.paternal.f1_assembly_v2_genbank.fa', 6143220) target region 4681644 - 5517829 len: 836185
# ('HG02055#1#JAHEPK010000106.1', 'HG02055.paternal.f1_assembly_v2_genbank.fa', 4361686) target region 161975 - 998193 len: 836218
# ('HG00621#1#JAHBCD010000042.1', 'HG00621.paternal.f1_assembly_v2_genbank.fa', 17250043) target region 7867808 - 9018707 len: 1150899
# ('HG02145#1#JAHKSG010000330.1', 'HG02145.paternal.f1_assembly_v2_genbank.fa', 692971) target region 127858 - 692668 len: 564810
# ('HG01928#1#JAGYVQ010000127.1', 'HG01928.paternal.f1_assembly_v2_genbank.fa', 8585374) target region 987125 - 1660973 len: 673848
# ('HG01106#1#JAHAMC010000079.1', 'HG01106.paternal.f1_assembly_v2_genbank.fa', 8358854) target region 387372 - 1354945 len: 967573
# ('HG002#1#JAHKSE010000127.1', 'HG002.paternal.f1_assembly_v2_genbank.fa', 3241961) target region 1591 - 417674 len: 416083
# ('HG03098#1#JAHEPM010000109.1', 'HG03098.paternal.f1_assembly_v2_genbank.fa', 8155788) target region 372836 - 1239076 len: 866240
# ('chrY_chm13', 'chm13_tagged.fa', 62460029) target region 8890399 - 10223763 len: 1333364
# ('HG02486#1#JAGYVM010000052.1', 'HG02486.paternal.f1_assembly_v2_genbank.fa', 3771468) target region 159045 - 954671 len: 795626
# ('HG01358#1#JAGYZB010000044.1', 'HG01358.paternal.f1_assembly_v2_genbank.fa', 12742626) target region 5124492 - 5818650 len: 694158
# ('HG005#1#JAHEPO010000078.1', 'HG005.paternal.f1_assembly_v2_genbank.fa', 3482312) target region 2803566 - 3335329 len: 531763
# ('HG02572#1#JAHAOW010000099.1', 'HG02572.paternal.f1_assembly_v2_genbank.fa', 7829890) target region 158420 - 933789 len: 775369
# ('HG01258#1#JAGYYV010000074.1', 'HG01258.paternal.f1_assembly_v2_genbank.fa', 7120004) target region 6893825 - 7119769 len: 225944
# ('HG02717#1#JAHAOS010000169.1', 'HG02717.paternal.f1_assembly_v2_genbank.fa', 477881) target region 98529 - 118177 len: 19648
# ('HG02145#1#JAHKSG010000442.1', 'HG02145.paternal.f1_assembly_v2_genbank.fa', 427417) target region 3531 - 256638 len: 253107
# ('HG02145#1#JAHKSG010000176.1', 'HG02145.paternal.f1_assembly_v2_genbank.fa', 2735443) target region 2334978 - 2354627 len: 19649
# ('HG01258#1#JAGYYV010000141.1', 'HG01258.paternal.f1_assembly_v2_genbank.fa', 905885) target region 4674 - 775510 len: 770836
# ('HG002#1#JAHKSE010000172.1', 'HG002.paternal.f1_assembly_v2_genbank.fa', 8998984) target region 8824489 - 8844129 len: 19640
# ('HG01952#1#JAHAME010000069.1', 'HG01952.paternal.f1_assembly_v2_genbank.fa', 8368882) target region 4023319 - 4033549 len: 10230
# ('HG01109#1#JAHEPA010000083.1', 'HG01109.paternal.f1_assembly_v2_genbank.fa', 8444572) target region 6897942 - 8027831 len: 1129889

# %%
plt.hist(rgn_lengths, bins=32);
plt.xlabel("ROI region size")
plt.ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
# Some mapped regions are larger, let's check the repeat / CNV by quick dot plots. We label the region of the ROI by two vertical grey lines. We observe that there are different number of intersections (~different copy number) of the region the "dots" due to the different repeat structures.

# %%
seq_list = []
i = 1
plt.figure(figsize=(24, 24))
for k in list(aln_range.keys()):
    ctg_name, source, _ = sdb.seq_info[k]
    seq_id = k
    rgns = aln_range[k].copy()

    rgns = pgrtk.merge_regions(rgns, tol=1000)

    for rgn in rgns:
        b, e, length, orientation, aln = rgn
        aln.sort()
  
        if aln[0][0][0] > padding or aln[-1][0][1] < padding + roi_len:
            continue
        
        #for illustration purpose, we only plot with the sequnce spanned through the whole region

        #if e-b < 0.75 * (roi_len + 2 * padding):             
        #    continue

        seq =  sdb.get_sub_seq(source, ctg_name, b, e)
  
        if orientation == 1:
            seq = pgrtk.rc_byte_seq(seq)

        seq_list.append(("{}_{}_{}_{}".format(ctg_name, b, e, orientation), seq))
        x, y = pgrtk.get_shmmr_dots(roi_seq, seq, 128, 32, 6, 1)
        
        if len(y) == 0:
            continue
        if i <= 36:
            plt.subplot(6,6,i)
            plt.plot(x, y, ".", markersize=0.1)
            plt.plot([padding, padding],[0, max(y)], color='grey')
            plt.plot([padding+roi_len, padding+roi_len],[0, max(y)], color='grey')
        i += 1

# %% [markdown]
# ## Create a new shimmer database for the detailed study

# %%
seq_list = []
seq_info = sdb.seq_info.copy()
i = 0
for k in list(aln_range.keys()):
    ctg_name, source, _ = seq_info[k]
    seq_id = k
    rgns = aln_range[k].copy()
    
    rgns = pgrtk.merge_regions(rgns,tol=1000)

    for rgn in rgns:
        b, e, length, orientation, aln = rgn
        
        #for illustration purpose, we only plot with the sequnce spanned through the whole region

        if e-b < 0.75 * (roi_len + 2 * padding):             
            continue
            
        seq =  sdb.get_sub_seq(source, ctg_name, b, e)
        if orientation == 1:
            seq = pgrtk.rc_byte_seq(seq)
  
        seq_list.append(("{}_{}_{}_{}".format(ctg_name, b, e, orientation), seq))
        
        i += 1

# %% [markdown]
# Create a shimmer indext database with smaller window (denser shimmers)

# %%
new_sdb = pgrtk.SeqIndexDB() 
new_sdb.load_from_seq_list(seq_list, w=128, k=56, r=12, min_span=28)

# %%
len(new_sdb.seq_info)
# Out:
# 13

# %%
#find hits in the pangenomic reference
aln_range0 = pgrtk.query_sdb(new_sdb, roi_seq, merge_range_tol=300000)

aln_range = aln_range0

print("The number of hits is", len(aln_range))

count = 0
for sid, rgns in aln_range.items():
    count += len(rgns)

print("The total aligned regions is", count)
# Out:
# The number of hits is 13
# The total aligned regions is 13

# %% [markdown]
# Let's loop through the hits (contigs that has alignments) and see the number of "copies".

# %%
from collections import Counter

# %%
n_copy = {}
for k in list(aln_range.keys()):
    n_copy[k] = len(aln_range[k])
copy_count = Counter(n_copy.values())
for nc, nh in copy_count.items():
    print("number of copy: {}, number of haplotypes: {}".format(nc, nh))
# Out:
# number of copy: 1, number of haplotypes: 13

# %%
rgn_lengths = []
for k in list(aln_range.keys()):
    for sid, rgns in aln_range.items():
        for rgn in rgns:
            b, e = rgn[0:2]
            #print(seq_index[k], "target region", b, "-", e, "len:", e-b )
            rgn_lengths.append(e-b)
plt.hist(rgn_lengths, bins=32);
plt.xlabel("ROI size")
plt.ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %%
f0 = open("/results/ROI_seq.fa", "w")
for ctg, seq in seq_list:
    
    print(">{}".format(ctg), file=f0)
    print(pgrtk.u8_to_string(seq), file=f0)
       
f0.close()

# %%
help(new_sdb.generate_mapg_gfa)
# Out:
# Help on built-in function generate_mapg_gfa:
#
# generate_mapg_gfa(...) method of builtins.SeqIndexDB instance
#     Convert the adjecent list of the shimmer graph shimmer_pair -> GFA
#
#     Parameters
#     ----------
#     min_count : int
#         the minimum number of times a pair of shimmers must be observed to be included in the graph
#
#     filenpath : string
#         the path to the output file
#
#     Returns
#     -------
#
#     None
#         The data is written into the file at filepath

# %%
new_sdb = pgrtk.SeqIndexDB() 
new_sdb.load_from_seq_list(seq_list, w=128, k=56, r=12, min_span=28)
new_sdb.generate_mapg_gfa(0, "/results/ROI_80_56_6.gfa")

new_sdb = pgrtk.SeqIndexDB() 
new_sdb.load_from_seq_list(seq_list, w=128, k=56, r=2, min_span=28)
new_sdb.generate_mapg_gfa(0, "/results/ROI_80_56_2.gfa")

# %% [markdown]
# ## Construct the genome graphs

# %%
import networkx as nx
from networkx.drawing import nx_pydot

# %%
def get_graph(seq_list, w=128, k=56, r=4, min_span=28, highlite=0):
    new_sdb = pgrtk.SeqIndexDB() 
    new_sdb.load_from_seq_list(seq_list, w=w, k=k, r=r, min_span=min_span)
    new_sdb.generate_mapg_gfa(0, f"/results/{name}-{w}-{k}-{r}.gfa")
    sid_to_path = {}
    spl=new_sdb.get_shmmr_pair_list()
    for (k0, k1, sid, p0, p1, o) in spl:
        sid_to_path.setdefault(sid,[])
        sid_to_path[sid].append((p0, p1, o, k0, k1))
    G = nx.DiGraph()
    m = new_sdb.get_shmmr_map()
    for sid, path in sid_to_path.items():
        #print(sid)
        path.sort()
        v = path[0]
        #if sid != 45:
        #    continue
        for w in path[1:]:
            v = tuple(v[-2:])
            w = tuple(w[-2:])
            color = "yellow"
            penwidth =  2 + 0.1 * (len(m[v]) * len(m[w])) ** 0.5
            G.add_edge(v, w, penwidth = penwidth, color="orange" )
            G.add_edge(w, v, penwidth = penwidth, color="orange" )
            G.add_node(v, fillcolor=color, style="filled")
            #G.add_node(w, size =  len(m[v]))
            v = w
            
    node_to_sid = {}
    for v in G.nodes():
        node_to_sid.setdefault(v, {})
        for sid, path in sid_to_path.items():
            node_to_sid[v][sid] = 0
            
     
    for sid, path in sid_to_path.items():
        #print(sid)
        path.sort()
        for v in path:
            v = tuple(v[-2:])
            node_to_sid[v][sid] = 1
    #nx.set_node_attributes(G, node_to_sid)  
    return G

# %%
def get_graph2(seq_list, w=128, k=56, r=4, min_span=28, highlite=0):
    new_sdb = pgrtk.SeqIndexDB() 
    new_sdb.load_from_seq_list(seq_list, w=w, k=k, r=r, min_span=min_span)
    new_sdb.generate_mapg_gfa(0, f"/results/{name}-{w}-{k}-{r}.gfa")
    sid_to_path = {}
    spl=new_sdb.get_shmmr_pair_list()
    for (k0, k1, sid, p0, p1, o) in spl:
        sid_to_path.setdefault(sid,[])
        sid_to_path[sid].append((p0, p1, o, k0, k1))
    G = nx.DiGraph()
    m = new_sdb.get_shmmr_map()
    for sid, path in sid_to_path.items():
        #print(sid)
        path.sort()
        v = path[0]
        #if sid != 45:
        #    continue
        for w in path[1:]:
            v = tuple(v[-2:])
            w = tuple(w[-2:])
            color = "yellow"
            penwidth =  1 + 0.02 * (len(m[v]) * len(m[w])) ** 0.5
            G.add_edge(v, w, penwidth = penwidth, color="orange" )
            G.add_edge(w, v, penwidth = penwidth, color="orange" )
            G.add_node(v, fillcolor=color, style="filled")
            #G.add_node(w, size =  len(m[v]))
            v = w
            
    for sid, path in sid_to_path.items():
        #print(sid)
        path.sort()
        v = path[0]
        if sid != highlite:
            continue
        for w in path[1:]:
            v = tuple(v[-2:])
            w = tuple(w[-2:])
            color = "blue"
            penwidth =  1 + 0.02 * (len(m[v]) * len(m[w])) ** 0.5
            G.add_node(v, fillcolor=color, style="filled")
            G.add_edge(v, w, penwidth = penwidth, color=color )
            G.add_edge(w, v, penwidth = penwidth, color=color )
            v = w
    return G

# %% [raw]
# for r in (12,4):
#     w=80; k=56;
#     name="ROI"
#     G = get_graph2(seq_list, w=w, k=k, r=r, highlite=0)
#
#     #nx.write_gexf(G, f"/results/{name}-{w}-{k}-{r}.gexf")
#     nx_pydot.write_dot(G, f"{name}-{w}-{k}-{r}.dot")
#     ## for this version of graphviz, we need to create PDF to get the bounding box right
#     os.system(f"""neato -Tpdf {name}-{w}-{k}-{r}.dot -x -Grankdir=LR -Gsize=64,64 \
#     -Nfixedsize=true -Nwidth=.5 -Nheight=.5 -Nlabel="" > {name}-{w}-{k}-{r}.pdf""")
#     os.system(f"""pdf2svg {name}-{w}-{k}-{r}.pdf {name}-{w}-{k}-{r}.svg""")

# %% [raw]
# for ht in range(0,12):
#     w=80; k=56; r=6;
#     name="ROI"
#     G = get_graph2(seq_list, w=w, k=k, r=r, highlite=ht)
#
#     #nx.write_gexf(G, f"/results/{name}-{w}-{k}-{r}.gexf")
#     nx_pydot.write_dot(G, f"{name}-{w}-{k}-{r}-h{ht}.dot")
#     ## for this version of graphviz, we need to create PDF to get the bounding box right
#     os.system(f"""neato -Tpdf {name}-{w}-{k}-{r}-h{ht}.dot -x -Grankdir=LR -Gsize=64,64 \
#     -Nfixedsize=true -Nwidth=.5 -Nheight=.5 -Nlabel="" > {name}-{w}-{k}-{r}-h{ht}.pdf""")
#     os.system(f"""pdf2svg {name}-{w}-{k}-{r}-h{ht}.pdf {name}-{w}-{k}-{r}-h{ht}.svg""")

# %% [markdown]
# ## Generate Repeat Pattern Using the Principal Bundles

# %%
len(seq_list)
# Out:
# 13

# %%
import numpy as np

# %%
shmmrspec = {"w": 80, "k":56, "r":4, "min_span":28 }
new_sdb = pgrtk.SeqIndexDB() 
new_sdb.load_from_seq_list(seq_list, 
                           w = shmmrspec["w"], 
                           k = shmmrspec["k"], 
                           r = shmmrspec["r"], 
                           min_span = shmmrspec["min_span"])

# %%
principal_bundles, sid_smps = new_sdb.get_principal_bundle_decomposition(0,8)
sid_smps = dict(sid_smps)
sid_to_smps = sid_smps # just an alias
print(len(principal_bundles))
# Out:
# 34

# %%
import numpy as np
from matplotlib import cm

# %%
cmap=plt.get_cmap("nipy_spectral")
cmap

# %%
lpb = len(principal_bundles)
color_theme0 = cmap(np.linspace(0.1, 0.9, lpb))
#pseudo-randomize the colors
idx = np.array([_ * (lpb+8011) for _ in range(lpb)]) % lpb
print(idx)
color_theme = color_theme0[idx]
# Out:
# [ 0 21  8 29 16  3 24 11 32 19  6 27 14  1 22  9 30 17  4 25 12 33 20  7
#  28 15  2 23 10 31 18  5 26 13]

# %%
from matplotlib.colors import to_hex as to_hex

# %%
new_sdb.generate_principal_mapg_gfa(0, 8, "/results/TSPY1_principal_48_56_4_28.gfa")

v_to_name = {}
v_to_bundle_id = {}
with open("/results/TSPY1_principal_48_56_4_28.gfa") as f:
    for r in f:
        r = r.strip().split("\t")
        if r[0] != "S":
            continue
        n = r[1]
        v = r[4].split(":")[-1]
        v_to_name[v] = n

f = open("/results/TSPY1_principal_48_56_4_28_color.csv", "w")
print("Name,Color,Bundle_ID", file=f)
for bundle in principal_bundles:
    bundle_id = bundle[0]
    for v in bundle[2]:
        vertex = tuple(v[:2])
        color = to_hex(color_theme[bundle_id])
  
        print(v_to_name["{:016x}_{:016x}".format(*vertex)], color, bundle_id, file=f, sep=",")
f.close()


new_sdb.generate_mapg_gfa(0, "/results/TSPY1_48_56_4_28.gfa")

v_to_name = {}
v_to_bundle_id = {}
with open("/results/TSPY1_48_56_4_28.gfa") as f:
    for r in f:
        r = r.strip().split("\t")
        if r[0] != "S":
            continue
        n = r[1]
        v = r[4].split(":")[-1]
        v_to_name[v] = n

f = open("/results/TSPY1_48_56_4_28_color.csv", "w")
print("Name,Color,Bundle_ID", file=f)
for bundle in principal_bundles:
    bundle_id = bundle[0]
    for v in bundle[2]:
        vertex = tuple(v[:2])
        color = to_hex(color_theme[bundle_id])
  
        print(v_to_name["{:016x}_{:016x}".format(*vertex)], color, bundle_id, file=f, sep=",")
f.close()

# %%
b_vertex_to_position = {}
i = 0
for bundle in principal_bundles:
    for v in bundle[2]:
        vertex = tuple(v[:2])
        b_vertex_to_position[vertex] = i, bundle[0]
        i += 1

# %%
seq_info = new_sdb.seq_info.copy()
sinfo = list(seq_info.items())
sinfo.sort(key=lambda x: x[1][0])

#fig = plt.figure(figsize=(24,96))
pidx = 1
for sid, data in sinfo[:10]:
    ctg, _, _ = data
    smps = sid_smps[sid]
    #print(seq_info[sid])
    #print(sid, len(smps))
    x, rx = [], []
    y, ry = [], []
    c, rc = [], []

   
    for s in smps:
        if s[1] is None:
            continue
        vertex = tuple(s[0][:2])
        x.append(s[0][2])
        y.append(b_vertex_to_position[vertex][0]) # same direction
        c.append(color_theme[s[1][0]])
            

    fig = plt.figure(figsize=(6,2))
    plt.scatter(x, y, marker=".", color=c, s=40)
    
    
    plt.xlim(-10000,1200000)
    plt.ylim(150,280)
    plt.title(ctg)

# %%
ref_file_name, roi1_chr, roi1_b, roi1_e = 'chm13_tagged.fa', 'chrY_chm13', 9775606, 9778403

padding = 100
roi1_seq = ref_db.get_sub_seq(ref_file_name, roi1_chr, roi1_b-padding, roi1_e+padding)

# %%
gene_matches1 = new_sdb.get_match_positions_with_fragment(roi1_seq)
gene_matches = [gene_matches1]

# %%
seq_info = new_sdb.seq_info.copy()
sinfo = list(seq_info.items())
sinfo.sort(key=lambda x: x[1][0])

fig = plt.figure(figsize=(24,48))
pidx = 1
for sid, data in sinfo:
    ctg, _, _ = data
    smps = sid_smps[sid]
    #print(seq_info[sid])
    #print(sid, len(smps))
    x, rx = [], []
    y, ry = [], []
    c, rc = [], []
    for s in smps:
        if s[1] is None:
            continue
        
        if s[0][4] == s[1][1]:
            x.append(s[0][2])
            y.append(0) # same direction
            c.append(color_theme[s[1][0]])
        else:
            rx.append(s[0][2])
            ry.append(6)
            rc.append(color_theme[s[1][0]])

            
    y = np.array(y) 
    ry = np.array(ry)
    x.reverse()
    c.reverse()
    
    plt.subplot(len(sid_smps), 1, pidx)
    pidx += 1
    
    #plt.figure(figsize=(24,3))
    plt.scatter(x, y, marker=">", color=c, s=80)
    plt.scatter(rx, ry, marker="<", color=rc, s=80)
    
    
    for mi in range(len(gene_matches)):
        matches = set([(_[0], _[1]) for _ in gene_matches[mi][sid]])
        track_x = [_[0] for _ in matches]
        plt.scatter(track_x, [-4-mi*2]*len(track_x), marker="s", color="black", s=2)
  
    
    
    
    #plt.axis("off")
    plt.yticks([])
    plt.ylim(-16,12)
    plt.xlim(-10000,1000000)
    plt.text(0, -15, ctg, fontsize=24)

# %%
pidx
# Out:
# 14

# %% [markdown]
# ## Repeat analsysis

# %%
bundle_id_count = []
for sid, data in sinfo:
    smps = sid_smps[sid]
    for s in smps:
        if s[1] is not None:
            bundle_id_count.append(s[1][0])
    
bundle_id_count = Counter(bundle_id_count)

# %%
principal_bundles_length = dict([ (_[0], len(_[2])) for _  in principal_bundles ])

# %%
repeat_bundles = set()
for bid, count in bundle_id_count.items():
    if count/principal_bundles_length[bid] > 14 * 3:
        print(bid, count/principal_bundles_length[bid])
        repeat_bundles.add(bid)
# Out:
# 8 236.0
# 10 187.66666666666666
# 16 175.5
# 6 190.0
# 3 296.2
# 15 175.0
# 9 139.66666666666666
# 14 66.0
# 13 85.5

# %%
repeat_bundles
# Out:
# {3, 6, 8, 9, 10, 13, 14, 15, 16}

# %%
sinfo = list(seq_info.items())
sinfo.sort(key=lambda x: x[1][0])
bundle_id_count = []
bundle_list = {}

# count most repeative bundle in a sequence
for seq_id, data in sinfo:

    smps = sid_smps[sid]

    bundle_list.setdefault(seq_id, [])
  
    for s in smps:
        if s[1] is None:
            continue
  
        smp = s[0]
        node = smp[0], smp[1]
        direction = smp[4]
        bundle_id = s[1][0]
        
        if bundle_id not in repeat_bundles:
            continue
  
        bundle_list[seq_id].append( bundle_id )

# %%
c = []
for seq_id, data in sinfo:
    c.extend(bundle_list[seq_id])
Counter(c).most_common(20)
# Out:
# [(3, 8307),
#  (6, 1924),
#  (8, 1235),
#  (10, 819),
#  (9, 598),
#  (16, 559),
#  (15, 520),
#  (14, 130),
#  (13, 117)]

# %%
### Fetch the repeat by breaking at the first shimmer pair of pincipal bundle 7 as it is more common element

# %%
repeat_start = {}
flag = 0
key_node = None
for seq_id, data in sinfo:
    ctg, src, _ = data
    #print(ctg, src)
    seq=new_sdb.get_seq_by_id(seq_id)
    smps = pgrtk.get_shmmr_pairs_from_seq(seq,  
                                          w = shmmrspec["w"], 
                                          k = shmmrspec["k"], 
                                          r = shmmrspec["r"],
                                          min_span = shmmrspec["min_span"])
    repeat_start.setdefault(seq_id, [])
    bundle_list.setdefault(seq_id, [])
    x = []
    
    for smp in smps:
        node = smp[0], smp[1]
        direction = smp[4]
        if node in b_vertex_to_position:
            if b_vertex_to_position[node][1] == 3:
                if flag == 0:
                    key_node = node
                    flag = 1
            else:
                flag = 0
                
            if key_node is not None and node == key_node:
                repeat_start[seq_id].append(smp[2])

# %%
f = open("/results/TSPY1_repeat_units_no_tail.fa", "w")
f2 = open("/results/TSPY1_repeat_tail_units.fa", "w")

for seq_id, data in sinfo:
    ctg, src, _ = data

    rs = repeat_start[seq_id]
   
    for i in range(len(rs)-1):
        b, e = rs[i], rs[i+1]
        seq = new_sdb.get_seq_by_id(seq_id)
        seq = pgrtk.u8_to_string(seq[b:e])
        if len(seq) < 15000 or len(seq) > 25000:
            continue
        print(f">{ctg}:{b}_{e}", file=f)
        print(f"{seq}", file=f)
        if len(seq) < 15000 or len(seq) > 25000:
            print(f">{ctg}:{b}_{e}", len(seq))
    
    b = rs[-1]
    e = b + 25000
    seq = new_sdb.get_seq_by_id(seq_id)
    seq = pgrtk.u8_to_string(seq[b:e])
    print(f">{ctg}:{b}_{e}", file=f2)
    print(f"{seq}", file=f2)
f.close()
f2.close()

# %%
# !cat /results/TSPY1_repeat_units_no_tail.fa /results/TSPY1_repeat_tail_units.fa > /results/TSPY1_repeat_units.fa

# %% [markdown]
# ## Analyzing the repeat units with PCA

# %%
shmmrspec = {"w": 58, "k":56, "r":1, "min_span":0 }
repeat_db = pgrtk.SeqIndexDB() 
repeat_db.load_from_fastx("/results/TSPY1_repeat_units.fa", 
                           w = shmmrspec["w"], 
                           k = shmmrspec["k"], 
                           r = shmmrspec["r"], 
                           min_span = shmmrspec["min_span"])

# %%
repeat_principal_bundles, repeat_sid_to_smps = repeat_db.get_principal_bundle_decomposition(0, 8);
repeat_sid_to_smps = dict(repeat_sid_to_smps)

# %%
lpb = len(repeat_principal_bundles)
print(lpb)
color_theme0 = cmap(np.linspace(0.1, 0.9, lpb))
#pseudo-randomize the colors
idx = np.array([_ * (lpb+8011 ) for _ in range(lpb)]) % lpb
print(idx)
color_theme = color_theme0[idx]
# Out:
# 108
# [  0  19  38  57  76  95   6  25  44  63  82 101  12  31  50  69  88 107
#   18  37  56  75  94   5  24  43  62  81 100  11  30  49  68  87 106  17
#   36  55  74  93   4  23  42  61  80  99  10  29  48  67  86 105  16  35
#   54  73  92   3  22  41  60  79  98   9  28  47  66  85 104  15  34  53
#   72  91   2  21  40  59  78  97   8  27  46  65  84 103  14  33  52  71
#   90   1  20  39  58  77  96   7  26  45  64  83 102  13  32  51  70  89]

# %% [markdown]
# get the vertex to bundle id map

# %%
vertex_to_bundle_id = {}
x = 0
bundle_id = 0
for bundle_id, order, bundle in repeat_principal_bundles:
    for v in bundle:
        vertex_to_bundle_id[tuple(v[:2])] = bundle_id, v[2]

# %% [markdown]
# ### Generate A GFA file of the repeat graph with pricinple bundle color annotation

# %%
from matplotlib.colors import to_hex as to_hex

# %%
repeat_db.generate_principal_mapg_gfa(0, 8, "/results/TSPY1_repeat_principal.gfa")

v_to_name = {}
v_to_bundle_id = {}
with open("/results/TSPY1_repeat_principal.gfa") as f:
    for r in f:
        r = r.strip().split("\t")
        if r[0] != "S":
            continue
        n = r[1]
        v = r[4].split(":")[-1]
        v_to_name[v] = n

f = open("/results/TSPY1_repeat_principal_color.csv", "w")
print("Name,Color,Bundle_ID", file=f)
for bundle in repeat_principal_bundles:
    bundle_id = bundle[0]
    for v in bundle[2]:
        vertex = tuple(v[:2])
        color = to_hex(color_theme[bundle_id])
  
        print(v_to_name["{:016x}_{:016x}".format(*vertex)], color, bundle_id, file=f, sep=",")
f.close()


repeat_db.generate_mapg_gfa(0, "/results/TSPY1_repeat.gfa")

v_to_name = {}
v_to_bundle_id = {}
with open("/results/TSPY1_repeat.gfa") as f:
    for r in f:
        r = r.strip().split("\t")
        if r[0] != "S":
            continue
        n = r[1]
        v = r[4].split(":")[-1]
        v_to_name[v] = n

f = open("/results/TSPY1_repeat_color.csv", "w")
print("Name,Color,Bundle_ID", file=f)
for bundle in repeat_principal_bundles:
    bundle_id = bundle[0]
    for v in bundle[2]:
        vertex = tuple(v[:2])
        color = to_hex(color_theme[bundle_id])
  
        print(v_to_name["{:016x}_{:016x}".format(*vertex)], color, bundle_id, file=f, sep=",")
f.close()

# %%
gene_matches1 = repeat_db.get_match_positions_with_fragment(roi1_seq)
gene_matches = [gene_matches1]

# %%
seq_info = repeat_db.seq_info.copy()
sinfo = list(seq_info.items())
sinfo.sort(key=lambda x: x[1][0])

fig = plt.figure(figsize=(24,48))
pidx = 1
for sid, data in sinfo[:144]:
    ctg, _, _ = data
    smps = repeat_sid_to_smps[sid]
    #print(seq_info[sid])
    #print(sid, len(smps))
    x, rx = [], []
    y, ry = [], []
    c, rc = [], []
    for s in smps:
        if s[1] is None:
            continue
        
        if s[0][4] == s[1][1]:
            x.append(s[0][2])
            y.append(0) # same direction
            c.append(color_theme[s[1][0]])
        else:
            rx.append(s[0][2])
            ry.append(6)
            rc.append(color_theme[s[1][0]])

            
    y = np.array(y) 
    ry = np.array(ry)
    x.reverse()
    c.reverse()
    
    plt.subplot(144, 1, pidx)
    pidx += 1
    
    #plt.figure(figsize=(24,3))
    plt.scatter(x, y, marker=">", color=c, s=80)
    plt.scatter(rx, ry, marker="<", color=rc, s=80)
    
    
    for mi in range(len(gene_matches)):
        if sid not in gene_matches[mi]: continue
        matches = set([(_[0], _[1]) for _ in gene_matches[mi][sid]])
        track_x = [_[0] for _ in matches]
        plt.scatter(track_x, [-7-mi*2]*len(track_x), marker="s", color="black", s=2)
    
    plt.axis("off")
    plt.yticks([])
    plt.ylim(-16,12)
    plt.xlim(-1000,25000)
    #plt.text(0, -15, ctg, fontsize=24)

# %% [markdown]
# Assign the position of each vertex in the principal bundle

# %%
b_vertex_to_position = {}
i = 0
for bundle in repeat_principal_bundles:
    if len(bundle[2]) == 1: # some small segment used in both directions
        continue
    for v in bundle[2]:
        vertex = tuple(v[:2])
        if vertex in b_vertex_to_position: # some small segment used in both directions
            continue
        b_vertex_to_position[vertex] = i, bundle[0]
        i += 1
print(i)
# Out:
# 1007

# %% [markdown]
# construct vector of each repet unit by the projection to the bundles

# %%
seq_info = repeat_db.seq_info.copy()

sinfo = list(seq_info.items())
sinfo.sort(key=lambda x: x[1][0])

s_vectors = np.zeros( (len(repeat_sid_to_smps), len(b_vertex_to_position)))

ctg_labels = [""]*len(repeat_sid_to_smps)


for sid, smps in repeat_sid_to_smps.items(): 
    ctg, src, _ = seq_info[sid]
    for smp, bundle_id in smps:
        if bundle_id is None:
            continue
        node = smp[0], smp[1]
        direction = smp[4]

        if node in b_vertex_to_position:
            s_vectors[sid, b_vertex_to_position[node][0]] = 1
    ctg_labels[sid]=ctg

# %% [markdown]
# ## filter out low count vertex

# %%
plt.plot(np.sum(s_vectors, axis=0))
idx = np.sum(s_vectors, axis=0) > 50
s_vectors = s_vectors[:, idx]

# %%
plt.figure(figsize=(10,6))
plt.matshow(s_vectors, fignum=1,  aspect='auto')

# %%
from sklearn.decomposition import PCA

# %%
sample2eth = {}
with open("/code/HPRC_y1_ethnic.csv") as f:
    for r in f:
        r = r.strip().split()
        sample2eth[r[0]] = r[2]

# %%
eths = []
for c in ctg_labels:
    #print(c, sample2eth.get(c.split("#")[0], "NA"))
    eths.append(sample2eth.get(c.split("#")[0], "NA"))

# %%
pca = PCA(n_components=2)
comp = pca.fit_transform(s_vectors)

[x, y] = zip( *[ (_[0], _[1]) for _ in comp ] )
c_map = {"AFR":"red", "AMR": "blue", "SAS": "orange", "EAS":"green" }
m_map = {"AFR":"o", "AMR": "^", "SAS": ">", "EAS":"d" }
colors = []

ax=plt.figure(figsize=(6,6))
for eth, color in c_map.items():
    xx = []
    yy = []
    for i in range(len(x)):
        #plt.text(x[i], y[i], eths[i])
        if eths[i] != eth:
            continue
        xx.append(x[i])
        yy.append(y[i])
    plt.scatter(xx, yy, alpha=0.2, marker=m_map[eth], c=color, s=50, label=eth)
plt.ylim(-8,8)
ax.legend(bbox_to_anchor=(0.850, 0.87), loc="upper right")

plt.xlabel("component 1")
plt.ylabel("component 2")
pca_x = x[:]
pca_y = y[:]
