# %% [markdown]
# ## Install the PGR-TK package

# %% [markdown]
# If neccessary, install the package into your python environment
# ```
# pip install --force /code/pgrtk-0.3.2-cp38-cp38-linux_x86_64.whl
# ```

# %%
import pgrtk
import os
import matplotlib.pyplot as plt
from IPython.display import SVG
# %matplotlib inline

# %%
pgrtk.__version__
# Out:
# 'pgrtk 0.3.2 (main:00d8eb3, release build, linux [x86_64] [rustc 1.62.0 (a8314ef7d 2022-06-27)])'

# %%
os.chdir("/results")

# %% [markdown]
# ## Lazy load the the AGCfile for fetching sequences## Load the hg19 reference into `ref_seq`

# %%
ref_db =pgrtk.AGCFile("/data/pgr-tk-HGRP-y1-evaluation-set-v0.agc")

# %% [markdown]
# ## Load the index into memory
# The loads the index into the memory. It takes about one minute.

# %%
# %%time
sdb = pgrtk.SeqIndexDB()
sdb.load_from_agc_index("/data/pgr-tk-HGRP-y1-evaluation-set-v0")
# Out:
# CPU times: user 20.4 s, sys: 2min 16s, total: 2min 36s
# Wall time: 2min 2s

# %% [markdown]
# We can see the specification about how SHIMMERs are computed using the `get_shmmr_spec()` method.

# %%
sdb.get_shmmr_spec() # window_size, k_mer_size, hieraical_reduction_factor, min_span, use_k_mer_sketch_other_than_minimizer
# Out:
# (80, 56, 4, 64, False)

# %% [markdown]
# ## Query the database with the sequence of the region

# %% [markdown]
# We use a copy of the annotation for IGV hg19 to look up the chromosome and locations of the gene of interest.
# We can fetch the region of interest with `ref_db`. Let's fetch the whole region and do a dot plot to examine the repeat structure.

# %%
ref_file_name, roi_chr, roi_b, roi_e = \
('hg38_tagged.fa', 
'chrY_hg38', 
23129355, 
23291356)
DAZ1_len = 23199094-23129355
DAZ2_len = 23291356-23219434
padding = 10000
roi_len = roi_e - roi_b
#get a segment of a reference
roi_seq = ref_db.get_sub_seq(ref_file_name, roi_chr, roi_b-padding, roi_e+padding)
x, y = pgrtk.get_shmmr_dots(roi_seq, roi_seq, 32, 32, 2, 2)
plt.plot(x, y, ".", markersize=0.5)
print(x[0])
plt.plot((padding, padding),(0,len(roi_seq)),'r')
plt.plot((padding+DAZ1_len, padding+DAZ1_len),(0,len(roi_seq)),'r')

plt.plot((padding+roi_len-DAZ2_len, padding+roi_len-DAZ2_len),(0,len(roi_seq)),'b')
plt.plot((padding+roi_len, padding+roi_len),(0,len(roi_seq)),'b')
plt.xlim(0,len(roi_seq))
plt.ylim(0,len(roi_seq))
# Out:
# 67
# (0.0, 182001.0)

# %%
#find hits in the pangenomic reference
aln_range = pgrtk.query_sdb(sdb, roi_seq, merge_range_tol=100000)

print("The number of hits is", len(aln_range))

count = 0
for sid, rgns in aln_range.items():
    count += len(rgns)

print("The total aligned regions is", count)
# Out:
# The number of hits is 42
# The total aligned regions is 66

# %% [markdown]
# We can examine, the target region sizes.

# %%
rgn_lengths = []
for k in list(aln_range.keys()):
    b, e = aln_range[k][0][0:2]
    print(sdb.seq_info[k], "target region", b, "-", e, "len:", e-b )
    rgn_lengths.append(e-b)
# Out:
# ('HG01928#1#JAGYVQ010000095.1', 'HG01928.paternal.f1_assembly_v2_genbank.fa', 6570700) target region 5931641 - 5943082 len: 11441
# ('chrY_hg38', 'hg38_tagged.fa', 57227415) target region 23119977 - 23300791 len: 180814
# ('HG03579#1#JAGYVU010000103.1', 'HG03579.paternal.f1_assembly_v2_genbank.fa', 5438582) target region 5259644 - 5274835 len: 15191
# ('chrY_hg19', 'hg19_tagged.fa', 59373566) target region 25266124 - 25446938 len: 180814
# ('HG01243#1#JAHEOY010000217.1', 'HG01243.paternal.f1_assembly_v2_genbank.fa', 540815) target region 450432 - 540578 len: 90146
# ('HG03492#1#JAHEPI010000146.1', 'HG03492.paternal.f1_assembly_v2_genbank.fa', 2434762) target region 628457 - 784081 len: 155624
# ('HG01243#1#JAHEOY010000211.1', 'HG01243.paternal.f1_assembly_v2_genbank.fa', 305726) target region 225170 - 305662 len: 80492
# ('HG002#1#JAHKSE010000343.1', 'HG002.paternal.f1_assembly_v2_genbank.fa', 426794) target region 230711 - 383975 len: 153264
# ('HG01106#1#JAHAMC010000114.1', 'HG01106.paternal.f1_assembly_v2_genbank.fa', 5959655) target region 1041977 - 1215634 len: 173657
# ('HG01952#1#JAHAME010000204.1', 'HG01952.paternal.f1_assembly_v2_genbank.fa', 793902) target region 743112 - 754553 len: 11441
# ('HG02145#1#JAHKSG010000620.1', 'HG02145.paternal.f1_assembly_v2_genbank.fa', 41904) target region 6391 - 40520 len: 34129
# ('HG03098#1#JAHEPM010000126.1', 'HG03098.paternal.f1_assembly_v2_genbank.fa', 2142417) target region 386 - 83089 len: 82703
# ('HG00673#1#JAHBBZ010000163.1', 'HG00673.paternal.f1_assembly_v2_genbank.fa', 5234378) target region 40631 - 203425 len: 162794
# ('HG005#1#JAHEPO010000082.1', 'HG005.paternal.f1_assembly_v2_genbank.fa', 4702648) target region 4526409 - 4702166 len: 175757
# ('HG02572#1#JAHAOW010000284.1', 'HG02572.paternal.f1_assembly_v2_genbank.fa', 2257599) target region 136850 - 287705 len: 150855
# ('HG01358#1#JAGYZB010000200.1', 'HG01358.paternal.f1_assembly_v2_genbank.fa', 497760) target region 83325 - 264143 len: 180818
# ('HG00621#1#JAHBCD010000079.1', 'HG00621.paternal.f1_assembly_v2_genbank.fa', 5011777) target region 27985 - 63149 len: 35164
# ('HG02055#1#JAHEPK010000089.1', 'HG02055.paternal.f1_assembly_v2_genbank.fa', 4592902) target region 232922 - 379020 len: 146098
# ('chrY_chm13', 'chm13_tagged.fa', 62460029) target region 23955627 - 24108893 len: 153266
# ('HG00673#1#JAHBBZ010000152.1', 'HG00673.paternal.f1_assembly_v2_genbank.fa', 1117026) target region 731918 - 819871 len: 87953
# ('HG01109#1#JAHEPA010000056.1', 'HG01109.paternal.f1_assembly_v2_genbank.fa', 1733726) target region 1006 - 84337 len: 83331
# ('HG02145#1#JAHKSG010000289.1', 'HG02145.paternal.f1_assembly_v2_genbank.fa', 2513666) target region 410 - 69377 len: 68967
# ('HG00621#1#JAHBCD010000098.1', 'HG00621.paternal.f1_assembly_v2_genbank.fa', 8936173) target region 43566 - 183511 len: 139945
# ('HG01358#1#JAGYZB010000050.1', 'HG01358.paternal.f1_assembly_v2_genbank.fa', 1345099) target region 1228900 - 1325445 len: 96545
# ('HG03579#1#JAGYVU010000167.1', 'HG03579.paternal.f1_assembly_v2_genbank.fa', 933953) target region 638153 - 826129 len: 187976
# ('HG02145#1#JAHKSG010000532.1', 'HG02145.paternal.f1_assembly_v2_genbank.fa', 216817) target region 128292 - 215199 len: 86907
# ('HG01928#1#JAGYVQ010000093.1', 'HG01928.paternal.f1_assembly_v2_genbank.fa', 5491480) target region 113189 - 274914 len: 161725
# ('HG01243#1#JAHEOY010000142.1', 'HG01243.paternal.f1_assembly_v2_genbank.fa', 1316235) target region 1269222 - 1276205 len: 6983
# ('HG02486#1#JAGYVM010000174.1', 'HG02486.paternal.f1_assembly_v2_genbank.fa', 950999) target region 255524 - 267734 len: 12210
# ('HG002#1#JAHKSE010000280.1', 'HG002.paternal.f1_assembly_v2_genbank.fa', 1803729) target region 410743 - 577243 len: 166500
# ('HG02717#1#JAHAOS010000072.1', 'HG02717.paternal.f1_assembly_v2_genbank.fa', 5924734) target region 5624525 - 5800567 len: 176042
# ('HG01109#1#JAHEPA010000300.1', 'HG01109.paternal.f1_assembly_v2_genbank.fa', 149915) target region 556 - 148879 len: 148323
# ('HG01106#1#JAHAMC010000088.1', 'HG01106.paternal.f1_assembly_v2_genbank.fa', 1720541) target region 263144 - 411628 len: 148484
# ('HG03492#1#JAHEPI010000441.1', 'HG03492.paternal.f1_assembly_v2_genbank.fa', 233584) target region 16363 - 185257 len: 168894
# ('HG03098#1#JAHEPM010000251.1', 'HG03098.paternal.f1_assembly_v2_genbank.fa', 38483) target region 779 - 33532 len: 32753
# ('HG01109#1#JAHEPA010000234.1', 'HG01109.paternal.f1_assembly_v2_genbank.fa', 150419) target region 849 - 64222 len: 63373
# ('HG02055#1#JAHEPK010000207.1', 'HG02055.paternal.f1_assembly_v2_genbank.fa', 151932) target region 135868 - 151522 len: 15654
# ('HG02717#1#JAHAOS010000170.1', 'HG02717.paternal.f1_assembly_v2_genbank.fa', 240141) target region 46966 - 193063 len: 146097
# ('HG01258#1#JAGYYV010000057.1', 'HG01258.paternal.f1_assembly_v2_genbank.fa', 6877804) target region 4439626 - 4608516 len: 168890
# ('HG02486#1#JAGYVM010000091.1', 'HG02486.paternal.f1_assembly_v2_genbank.fa', 1628709) target region 369785 - 545832 len: 176047
# ('HG01952#1#JAHAME010000112.1', 'HG01952.paternal.f1_assembly_v2_genbank.fa', 4209224) target region 3813861 - 3970821 len: 156960
# ('HG01106#2#JAHAMB010000119.1', 'HG01106.maternal.f1_assembly_v2_genbank.fa', 1601699) target region 166781 - 315265 len: 148484

# %%
plt.hist(rgn_lengths, bins=32);
plt.xlabel("ROI size")
plt.ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
# Some mapped regions are larger, let's check the repeat / CNV by quick dot plots. We label the region of the ROI by two vertical grey lines. We observe that there are different number of intersections (~different copy number of the ROI) of the region the "dots" due to the different repeat structures.

# %%
seq_list = []
i = 1
plt.figure(figsize=(24, 24))
for k in list(aln_range.keys()):
    ctg_name, source, _ = sdb.seq_info[k]
    seq_id = k
    rgns = aln_range[k].copy()

    rgns = pgrtk.merge_regions(rgns, tol=1000)

    for rgn in rgns:
        b, e, length, orientation, aln = rgn
        aln.sort()
  
        #if aln[0][0][0] > padding or aln[-1][0][1] < padding + roi_len:
        #    continue
        
        #for illustration purpose, we only plot with the sequnce spanned through the whole region

        if e-b < 0.75 * (roi_len + 2 * padding):             
            continue

        seq =  sdb.get_sub_seq(source, ctg_name, b, e)
  
        if orientation == 1:
            seq = pgrtk.rc_byte_seq(seq)

        seq_list.append(("{}_{}_{}_{}".format(ctg_name, b, e, orientation), seq))
        x, y = pgrtk.get_shmmr_dots(roi_seq, seq, 32, 32, 1, 1)
        
        
        if i <= 36:
            plt.subplot(6,6,i)
            plt.plot(x, y, ".", markersize=0.1)
            plt.plot([padding, padding],[0, max(y)], color='grey')
            plt.plot([padding+roi_len, padding+roi_len],[0, max(y)], color='grey')
        i += 1

# %% [markdown]
# ## Create a new shimmer database for the detailed study

# %%
seq_list = []
seq_info = sdb.seq_info.copy()
i = 0
for k in list(aln_range.keys()):
    ctg_name, source, _ = seq_info[k]
    seq_id = k
    rgns = aln_range[k].copy()
    
    rgns = pgrtk.merge_regions(rgns,tol=1000)

    for rgn in rgns:
        b, e, length, orientation, aln = rgn
        
        #for illustration purpose, we only plot with the sequnce spanned through the whole region

        if e-b < 0.75 * (roi_len + 2 * padding):             
            continue
            
        seq =  sdb.get_sub_seq(source, ctg_name, b, e)
        if orientation == 1:
            seq = pgrtk.rc_byte_seq(seq)
  
        seq_list.append(("{}_{}_{}_{}".format(ctg_name, b, e, orientation), seq))
        
        i += 1

# %% [markdown]
# Create a shimmer indext database with smaller window (denser shimmers)

# %%
new_sdb = pgrtk.SeqIndexDB() 
new_sdb.load_from_seq_list(seq_list, w=80, k=56, r=6, min_span=18)

# %%
len(new_sdb.seq_info)
# Out:
# 36

# %%
#find hits in the pangenomic reference
aln_range0 = pgrtk.query_sdb(new_sdb, roi_seq, merge_range_tol=300000)

aln_range = aln_range0

print("The number of hits is", len(aln_range))

count = 0
for sid, rgns in aln_range.items():
    count += len(rgns)

print("The total aligned regions is", count)
# Out:
# The number of hits is 36
# The total aligned regions is 45

# %% [markdown]
# Let's loop through the hits (contigs that has alignments) and see the number of "copies".

# %%
from collections import Counter

# %%
n_copy = {}
for k in list(aln_range.keys()):
    n_copy[k] = len(aln_range[k])
copy_count = Counter(n_copy.values())
for nc, nh in copy_count.items():
    print("number of copy: {}, number of haplotypes: {}".format(nc, nh))
# Out:
# number of copy: 2, number of haplotypes: 9
# number of copy: 1, number of haplotypes: 27

# %%
rgn_lengths = []
for k in list(aln_range.keys()):
    for sid, rgns in aln_range.items():
        for rgn in rgns:
            b, e = rgn[0:2]
            #print(seq_index[k], "target region", b, "-", e, "len:", e-b )
            rgn_lengths.append(e-b)
plt.hist(rgn_lengths, bins=32);
plt.xlabel("ROI size")
plt.ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %%
f0 = open("/results/ROI_seq.fa", "w")
for ctg, seq in seq_list:
    
    print(">{}".format(ctg), file=f0)
    print(pgrtk.u8_to_string(seq), file=f0)
       
f0.close()

# %%
new_sdb = pgrtk.SeqIndexDB() 
new_sdb.load_from_seq_list(seq_list, w=80, k=56, r=6, min_span=18)
new_sdb.generate_mapg_gfa(0, "/results/ROI_80_56_6.gfa")

new_sdb = pgrtk.SeqIndexDB() 
new_sdb.load_from_seq_list(seq_list, w=80, k=56, r=2, min_span=18)
new_sdb.generate_mapg_gfa(0, "/results/ROI_80_56_2.gfa")

# %% [markdown]
# ## Construct the genome graphs

# %%
import networkx as nx
from networkx.drawing import nx_pydot

# %%
def get_graph(seq_list, w=128, k=56, r=4, min_span=28, highlite=0):
    new_sdb = pgrtk.SeqIndexDB() 
    new_sdb.load_from_seq_list(seq_list, w=w, k=k, r=r, min_span=min_span)
    new_sdb.generate_mapg_gfa(0, f"/results/{name}-{w}-{k}-{r}.gfa")
    sid_to_path = {}
    spl=new_sdb.get_shmmr_pair_list()
    for (k0, k1, sid, p0, p1, o) in spl:
        sid_to_path.setdefault(sid,[])
        sid_to_path[sid].append((p0, p1, o, k0, k1))
    G = nx.DiGraph()
    m = new_sdb.get_shmmr_map()
    for sid, path in sid_to_path.items():
        #print(sid)
        path.sort()
        v = path[0]
        #if sid != 45:
        #    continue
        for w in path[1:]:
            v = tuple(v[-2:])
            w = tuple(w[-2:])
            color = "yellow"
            penwidth =  2 + 0.1 * (len(m[v]) * len(m[w])) ** 0.5
            G.add_edge(v, w, penwidth = penwidth, color="orange" )
            G.add_edge(w, v, penwidth = penwidth, color="orange" )
            G.add_node(v, fillcolor=color, style="filled")
            #G.add_node(w, size =  len(m[v]))
            v = w
            
    node_to_sid = {}
    for v in G.nodes():
        node_to_sid.setdefault(v, {})
        for sid, path in sid_to_path.items():
            node_to_sid[v][sid] = 0
            
     
    for sid, path in sid_to_path.items():
        #print(sid)
        path.sort()
        for v in path:
            v = tuple(v[-2:])
            node_to_sid[v][sid] = 1
    #nx.set_node_attributes(G, node_to_sid)  
    return G

# %%
def get_graph2(seq_list, w=128, k=56, r=4, min_span=28, highlite=0):
    new_sdb = pgrtk.SeqIndexDB() 
    new_sdb.load_from_seq_list(seq_list, w=w, k=k, r=r, min_span=min_span)
    new_sdb.generate_mapg_gfa(0, f"/results/{name}-{w}-{k}-{r}.gfa")
    sid_to_path = {}
    spl=new_sdb.get_shmmr_pair_list()
    for (k0, k1, sid, p0, p1, o) in spl:
        sid_to_path.setdefault(sid,[])
        sid_to_path[sid].append((p0, p1, o, k0, k1))
    G = nx.DiGraph()
    m = new_sdb.get_shmmr_map()
    for sid, path in sid_to_path.items():
        #print(sid)
        path.sort()
        v = path[0]
        #if sid != 45:
        #    continue
        for w in path[1:]:
            v = tuple(v[-2:])
            w = tuple(w[-2:])
            color = "yellow"
            penwidth =  1 + 0.02 * (len(m[v]) * len(m[w])) ** 0.5
            G.add_edge(v, w, penwidth = penwidth, color="orange" )
            G.add_edge(w, v, penwidth = penwidth, color="orange" )
            G.add_node(v, fillcolor=color, style="filled")
            #G.add_node(w, size =  len(m[v]))
            v = w
            
    for sid, path in sid_to_path.items():
        #print(sid)
        path.sort()
        v = path[0]
        if sid != highlite:
            continue
        for w in path[1:]:
            v = tuple(v[-2:])
            w = tuple(w[-2:])
            color = "blue"
            penwidth =  1 + 0.02 * (len(m[v]) * len(m[w])) ** 0.5
            G.add_node(v, fillcolor=color, style="filled")
            G.add_edge(v, w, penwidth = penwidth, color=color )
            G.add_edge(w, v, penwidth = penwidth, color=color )
            v = w
    return G

# %% [raw]
# for r in (12,4):
#     w=80; k=56;
#     name="ROI"
#     G = get_graph2(seq_list, w=w, k=k, r=r, highlite=0)
#
#     #nx.write_gexf(G, f"/results/{name}-{w}-{k}-{r}.gexf")
#     nx_pydot.write_dot(G, f"{name}-{w}-{k}-{r}.dot")
#     ## for this version of graphviz, we need to create PDF to get the bounding box right
#     os.system(f"""neato -Tpdf {name}-{w}-{k}-{r}.dot -x -Grankdir=LR -Gsize=64,64 \
#     -Nfixedsize=true -Nwidth=.5 -Nheight=.5 -Nlabel="" > {name}-{w}-{k}-{r}.pdf""")
#     os.system(f"""pdf2svg {name}-{w}-{k}-{r}.pdf {name}-{w}-{k}-{r}.svg""")

# %% [raw]
# for ht in range(0,12):
#     w=80; k=56; r=6;
#     name="ROI"
#     G = get_graph2(seq_list, w=w, k=k, r=r, highlite=ht)
#
#     #nx.write_gexf(G, f"/results/{name}-{w}-{k}-{r}.gexf")
#     nx_pydot.write_dot(G, f"{name}-{w}-{k}-{r}-h{ht}.dot")
#     ## for this version of graphviz, we need to create PDF to get the bounding box right
#     os.system(f"""neato -Tpdf {name}-{w}-{k}-{r}-h{ht}.dot -x -Grankdir=LR -Gsize=64,64 \
#     -Nfixedsize=true -Nwidth=.5 -Nheight=.5 -Nlabel="" > {name}-{w}-{k}-{r}-h{ht}.pdf""")
#     os.system(f"""pdf2svg {name}-{w}-{k}-{r}-h{ht}.pdf {name}-{w}-{k}-{r}-h{ht}.svg""")

# %% [markdown]
# ## Generate Repeat Pattern Using the Principal Bundles

# %%
shmmrspec = {"w": 64, "k":56, "r":1, "min_span":28 }
new_sdb = pgrtk.SeqIndexDB() 
new_sdb.load_from_seq_list(seq_list, 
                           w = shmmrspec["w"], 
                           k = shmmrspec["k"], 
                           r = shmmrspec["r"], 
                           min_span = shmmrspec["min_span"])

# %%
principal_bundles, sid_smps = new_sdb.get_principal_bundle_decomposition(0,8)
sid_smps = dict(sid_smps)
print(len(principal_bundles))
# Out:
# 22

# %%
import numpy as np
from matplotlib import cm

# %%
cmap=plt.get_cmap("nipy_spectral")
cmap

# %%
lpb = len(principal_bundles)
color_theme0 = cmap(np.linspace(0.1, 0.9, lpb))
#pseudo-randomize the colors
idx = np.array([_ * (8011*5) for _ in range(lpb)]) % lpb
print(idx)
color_theme = color_theme0[idx]
# Out:
# [ 0 15  8  1 16  9  2 17 10  3 18 11  4 19 12  5 20 13  6 21 14  7]

# %%
new_sdb.generate_mapg_gfa(0, "/results/test_48_56_4_28.gfa")

v_to_name = {}
with open("/results/test_48_56_4_28.gfa") as f:
    for r in f:
        r = r.strip().split("\t")
        if r[0] != "S":
            continue
        n = r[1]
        v = r[4].split(":")[-1]
        v_to_name[v] = n

f = open("/results/test_48_56_4_28_color.csv", "w")
print("Name,Color", file=f)
for bundle_id, bundle in enumerate(principal_bundles):
    for v in bundle[2]:
        vertex = tuple(v[:2])
        color = color_theme[bundle_id]
  
        print(v_to_name["{:016x}_{:016x}".format(*vertex)], color, file=f, sep=",")
f.close()

# %%
b_vertex_to_position = {}
i = 0
for bundle in principal_bundles:
    for v in bundle[2]:
        vertex = tuple(v[:2])
        b_vertex_to_position[vertex] = i, bundle[0]
        i += 1

# %%
seq_info = new_sdb.seq_info.copy()
sinfo = list(seq_info.items())
sinfo.sort(key=lambda x: x[1][0])

#fig = plt.figure(figsize=(24,96))
pidx = 1
for sid, data in sinfo[:10]:
    ctg, _, _ = data
    smps = sid_smps[sid]
    #print(seq_info[sid])
    #print(sid, len(smps))
    x, rx = [], []
    y, ry = [], []
    c, rc = [], []

   
    for s in smps:
        if s[1] is None:
            continue
        vertex = tuple(s[0][:2])
        x.append(s[0][2])
        y.append(b_vertex_to_position[vertex][0]) # same direction
        c.append(color_theme[s[1][0]])
            

    fig = plt.figure(figsize=(6,2))
    plt.scatter(x, y, marker=".", color=c, s=40)
    
    
    plt.xlim(-10000,200000)
    plt.title(ctg)

# %%
ref_file_name, daz1_chr, daz1_b, daz1_e = \
('hg38_tagged.fa', 
'chrY_hg38', 23129355, 
23199094)
DAZ1_len = 23199094-23129355
DAZ2_len = 23291356-23219434
padding = 100
#roi_len = roi_e - roi_b
#get a segment of a reference
DAZ1_seq = ref_db.get_sub_seq(ref_file_name, daz1_chr, daz1_b-padding, daz1_e+padding)

ref_file_name, daz2_chr, daz2_b, daz2_e = \
('hg38_tagged.fa', 
'chrY_hg38', 23219434, 
23291356)
DAZ1_len = 23199094-23129355
DAZ2_len = 23291356-23291356
padding = 100
#roi_len = roi_e - roi_b
#get a segment of a reference
DAZ2_seq = ref_db.get_sub_seq(ref_file_name, daz2_chr, daz2_b-padding, daz2_e+padding)

ref_file_name, daz3_chr, daz3_b, daz3_e = \
('hg38_tagged.fa', 
'chrY_hg38', 24763069, 
24813492)

padding = 100
#roi_len = roi_e - roi_b
#get a segment of a reference
DAZ3_seq = ref_db.get_sub_seq(ref_file_name, daz3_chr, daz3_b-padding, daz3_e+padding)


ref_file_name, daz4_chr, daz4_b, daz4_e = \
('hg38_tagged.fa', 
'chrY_hg38', 24833919, 
24907040)

padding = 100
#roi_len = roi_e - roi_b
#get a segment of a reference
DAZ4_seq = ref_db.get_sub_seq(ref_file_name, daz4_chr, daz4_b-padding, daz4_e+padding)

# %%
gene_matches1 = new_sdb.get_match_positions_with_fragment(DAZ1_seq)
gene_matches2 = new_sdb.get_match_positions_with_fragment(DAZ2_seq)
gene_matches3 = new_sdb.get_match_positions_with_fragment(DAZ3_seq)
gene_matches4 = new_sdb.get_match_positions_with_fragment(DAZ4_seq)
gene_matches = [gene_matches1, gene_matches2, gene_matches3, gene_matches4]

# %%
seq_info = new_sdb.seq_info.copy()
sinfo = list(seq_info.items())
sinfo.sort(key=lambda x: x[1][0])

fig = plt.figure(figsize=(24,64))
# pidx = 1
for sid, data in sinfo:
    ctg, _, _ = data
    smps = sid_smps[sid]
    #print(seq_info[sid])
    #print(sid, len(smps))
    x, rx = [], []
    y, ry = [], []
    c, rc = [], []
    for s in smps:
        if s[1] is None:
            continue
        
        if s[0][4] == s[1][1]:
            x.append(s[0][2])
            y.append(0) # same direction
            c.append(color_theme[s[1][0]])
        else:
            rx.append(s[0][2])
            ry.append(6)
            rc.append(color_theme[s[1][0]])

            
    y = np.array(y) 
    ry = np.array(ry)
    x.reverse()
    c.reverse()
    
    # plt.subplot(len(sid_smps), 1, pidx)
    # pidx += 1
    
    plt.figure(figsize=(24,3))
    plt.scatter(x, y, marker=">", color=c, s=180)
    plt.scatter(rx, ry, marker="<", color=rc, s=180)
    
    
    for mi in range(4):
        matches = set([(_[0], _[1]) for _ in gene_matches[mi][sid]])
        track_x = [_[0] for _ in matches]
        plt.scatter(track_x, [-4-mi*2]*len(track_x), marker="s", color="black", s=2)
  
    
    
    #track0_x = [_[0] for _ in gene_matches[sid]]
    #plt.scatter(track0_x, [-6]*len(track0_x), marker="s", color="black", s=20)
    
    #plt.axis("off")
    plt.yticks([])
    plt.ylim(-16,12)
    plt.xlim(-10000,175000)
    plt.text(0, -15, ctg, fontsize=24)
# Out:
# <ipython-input-50-8bf53c3db4f0>:37: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(24,3))
